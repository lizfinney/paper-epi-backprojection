# %% [markdown]
# <a id="0"></a> <br>
#  # Table of Contents
# 1. [Packages and variables](#1)
# 1. [Files](#2)
# 1. [Initial population object](#3)
# 1. [Branching process](#4)
#     1. [Parallel processing](#5)
# 1. [Shuffle](#6)
#     1. [Parallel processing](#7)
#     1. [Large object running] (#8)
#     1. [Local running](#9)
# 1. [Back projection: application](#10)
#     1. [Parallel processing](#11)
#     1. [Large object running](#12)
#     1. [Local running](#13)
# 1. [Back projection: reformatting](#14)
#     1. [Parallel processing](#15)
#     1. [Large object running](#16)
#     1. [Local running](#17)
# 1. [Inference](#18)

# %% [markdown]
# <a id="1"></a>
# ##  packages and global variables

# %%
# import modules and global variables

from imp import reload
import sys, os
import shutil
import posixpath as ppath
from copy import deepcopy
import time
print('python version %s' % sys.version)

import numpy as np
print('numpy version %s' % np.__version__)

import scipy as sp
import scipy.stats as st
print('scipy version %s' % sp.__version__)

import pandas as pd
print('pandas version %s' % pd.__version__)

import matplotlib
from matplotlib import cm
import matplotlib.pyplot as plt
print('matplotlib version %s' % matplotlib.__version__)

import sklearn as sk
from sklearn.metrics import roc_auc_score
print('scikit-learn version %s' % sk.__version__)

# global variables
# replace with your directories here

USER_NAME         = 'YOUR_LOCAL_PATH'

SIM_DIR           = os.path.join(USER_NAME, 'paper-epi-backprojection/src/simulations')
DATA_SIM_DIR      = os.path.join(SIM_DIR, 'data-sim')
SCRIPT_DIR        = os.path.join(SIM_DIR, 'simulation-scripts')
DATA_FILES        = OS.path.join(DATA_SIM_DIR, 'data-npz')
STOC_LOC          = os.path.join(DATA_SIM_DIR, 'stoc-format')
BP_LOC_DIR        = os.path.join(DATA_SIM_DIR, 'back-projected-data-sim')
BP_LOC_DIR_WRITE  = os.path.join(DATA_SIM_DIR, 'back-projected-data-sim-write')

# cluster directory setup
DATA_DATE         = 'RUN_DATE_HERE'
SSH_USER          = 'YOUR_CLUSTER_NAME'
SSH_HOME          = 'YOUR_SSH_SERVER'
SSH_DATA          = ppath.join('YOUR_CLUSTER_DIRECTORY' SSH_USER, 'simulations', DATA_DATE)
BP_PROJ_DIR       = ppath.join(SSH_DATA, 'back-projected-func-sim10000')
BP_PROJ_DIR_WRITE = ppath.join(SSH_DATA, 'back-projected-func-write-sim10000')
SCRATCH           = ppath.join(SSH_DATA, 'scratch')
# Out:
# python version 3.9.7 (default, Sep 16 2021, 08:50:36)
# [Clang 10.0.0 ]
# numpy version 1.20.3
# scipy version 1.7.1
# pandas version 1.3.4
# matplotlib version 3.4.3

# %% [markdown]
# ### make directories

# %%
print(f'mkdir -p {SSH_DATA} &&')

# Make back projection write folders on directory

#print(f'mkdir {BP_PROJ_DIR} &&')
print(f'mkdir {BP_PROJ_DIR_WRITE} &&')

# create write sub directories

dir_list = []
for i in range(10000):
    dir_str = f'{bp_write_str}/df_{i}'
    dir_list.append(dir_str)

for name in dir_list:
    dir_path = ppath.join(SSH_DATA, name)
    if name!=dir_list[-1]:
        print(f'mkdir {dir_path} &&')
    else:
        print(f'mkdir {dir_path}')

# %% [markdown]
# <a id="2"></a>
# ## file naming

# %%
# base names for naming

sim_name = 'sim-samp100-T100-sim100-redo'
inf_name = 'inf-samp100-T100-sim100-redo'

init_file = os.path.join(SIM_DIR, "initial_sel_pop.npz")

# scripts and out files

# scripts

sim_script = os.path.join(SCRIPT_DIR, 'branching.py')
inf_script = os.path.join(SCRIPT_DIR, 'epi-infer-multiple.py')

# file containing the stochastic branching process simulation

sim_out       = os.path.join(SIM_DIR, sim_name + '-stochastic')
sim_clust     = os.path.join(SSH_DATA, sim_name + '-stochastic')
sim_npz       = sim_out + '.npz'
sim_npz_clust = sim_clust + '.npz'

# file containing the inference from the branching process

inf_out    = os.path.join(SIM_DIR, inf_name + '-stochastic')

# shuffling files

sim_shuff_out = os.path.join(SIM_DIR, sim_name + '-shuffled')
inf_shuff_out = os.path.join(SIM_DIR, inf_name + '-shuffled')

# back-projection files

bp_script = 'back_projection_ems.py'
incubation_file = 'incubation_period_sars2.csv'
smoothing_file = 'weights_binom.csv'

bp_script_path = os.path.join(SIM_DIR, bp_script)
inc_path = os.path.join(SIM_DIR, incubation_file)
smooth_path = os.path.join(SIM_DIR, smoothing_file)

# %% [markdown]
# ### Transfer files to the cluster

# %%
# Transfer files to the cluster
print(f'scp {sim_script} {SSH_HOME}{SSH_DATA} &&')
print(f'scp {inf_script} {SSH_HOME}{SSH_DATA} &&')
print(f'scp {bp_script_path} {SSH_HOME}{SSH_DATA} &&')
print(f'scp {inc_path} {SSH_HOME}{SSH_DATA} &&')
print(f'scp {smooth_path} {SSH_HOME}{SSH_DATA}')

# %% [markdown]
# <a id="3"></a>
# ## initial population object

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>ALREADY RUN</b> can edit parameters for other initial files
# </div>

# %%
# make initial population

# the starting population sizes for 6 variants
init_pop = [1000, 1000, 1000, 1000,  1000,  1000]
# the initial sequences where numbers specify location on the genome of a mutation
init_seqs = [[0],  [1],  [2],  [3],   [4],   [5]]
# the selection coefficients for the mutations, in order of site numbers
init_sel = [0,    0, 0.03, 0.03, -0.03, -0.03]

# initialize numpy object

init_file = os.path.join(SIM_DIR, "initial_sel_pop.npz")
f = open(init_file, mode='wb')
np.savez_compressed(f, counts=init_pop,
                    sequences=init_seqs, selection=init_sel)
f.close()

# %% [markdown]
# <a id="4"></a>
# ## run branching process

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>ALREADY RUN</b>
# </div>

# %%
command = f"%run {sim_script} -o {sim_out} --simulations 100 --pop_limit 10000 --sample 100 --mu 0 -T 100 -i {init_file}"

# %%
command
# Out:
# '%run /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/simulation-scripts/branching.py -o /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/sim-samp100-T100-sim100-redo-stochastic --simulations 100 --pop_limit 10000 --sample 100 --mu 0 -T 100 -i /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/initial_sel_pop.npz'

# %%
# your global variables here
# %run {SCRIPT_DIR}/branching.py -o {DATA_FILES}/initial_sel_pop.npz
# Out:
# /Users/liz/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
#%%time

# run branching process script for 100 simulations

# %run {sim_script} -o {sim_out} --simulations 100 --pop_limit 10000 --sample 100 --mu 0 -T 100 \
-i {init_file}

# %% [markdown]
# <a id="5"></a>
# ### run branching process, parallel

# %%
# %%time

# run branching process for 1000 simulations, 10 times

init_file = os.path.join(SIM_DIR, "initial_sel_pop.npz")

sim_script = os.path.join(SCRIPT_DIR, 'branching.py')

sim_name = 'sim-samp100-T100-sim1000'

sims = []

for i in range(10):
    sim_out_i = os.path.join(SIM_DIR, sim_name + f'-stochastic-{i}')
    sims.append(sim_out_i)
    
for i in sims:
    # %run {sim_script} -o {i} --simulations 1000 --pop_limit 10000 --sample 100 --mu 0 -T 100 \
    -i {init_file}

# %% [markdown]
# ### load branching simulation for checks
# #### optional

# %%
with np.load('sim-samp100-T100-sim10000-stochastic.npz', allow_pickle=True) as data:
    times = data['times']
    mutant_sites_all = data['mutant_sites_all']
    simulations = data['simulations']
    full_nVec = data['full_nVec']
    full_sVec = data['full_sVec']
    
with np.load('sim-samp100-T100-sim10000-shuffled.npz', allow_pickle=True) as data_sh:
    times_sh = data_sh['times']
    mutant_sites_all_sh = data_sh['mutant_sites_all']
    simulations_sh = data_sh['simulations']
    full_nVec_sh = data_sh['full_nVec']
    full_sVec_sh = data_sh['full_sVec']
    
with np.load('sim-samp100-T100-sim10000-backprojected.npz', allow_pickle=True) as data_bp:
    times_bp = data_bp['times']
    mutant_sites_all_bp = data_bp['mutant_sites_all']
    simulations_bp = data_bp['simulations']
    full_nVec_bp = data_bp['full_nVec']
    full_sVec_bp = data_bp['full_sVec']

# %% [markdown]
# <a id="6"></a>
# ## shuffle up times
# the script will create an npz file and split up alleles for each simulation into subfolders for backprojection

# %% [markdown]
# <a id="7"></a>
# ### parallel running

# %%
back_dir_str       = 'back-projected-sim1000'

dirs_list = []
for i in range(10):
    for j in range(1000):
        dir_str = back_dir_str + f'-{i}'
        dirs_list.append(dir_str)

for name in dirs_list:
    dir_path = ppath.join(SSH_DATA, name)
    if name!=dirs_list[-1]:
        print(f'mkdir {dir_path} &&')
    else:
        print(f'mkdir {dir_path}')

# %%
# parallel

script_file            = 'stochastic-shuffle.py'
script_path            = ppath.join(SIM_DIR, script_file)
script_path_clust      = ppath.join(SSH_DATA, script_file)
sim_read_str       = 'sim-samp100-T100-sim1000-stochastic'
back_dir_str       = 'back-projected-sim1000'

job_file         = 'job-shuff-1000-array.sh'
job_str          = f"""#!/bin/bash -l
#!/bin/bash
#SBATCH --job-name=stochastic-shuffle
#SBATCH --output=stoc-shuff-%a.out
#SBATCH --error=stoc-shuff-%a.err
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=1
#SBATCH --mem=16G
#SBATCH --mail-user={USER_EMAIL}
#SBATCH --mail-type=ALL
#SBATCH --time=04:00:00
#SBATCH --array=0-9

module unload miniconda2
module load miniconda3
conda activate sars-env

export PYTHONUNBUFFERED=1

# scripts takes the file path of the directory as input parameter

npz_files=({SSH_DATA}/{sim_read_str}-*.npz) # Create a Bash array with all f
npz_base=({sim_read_str}-*)
PROJ_DIRS=({SSH_DATA}/{back_dir_str}_*/)

module unload miniconda2
module load miniconda3
conda activate sars-env

# Feed the script with the data directory and file names corresponding to the task ID in the array

python {script_file} -npz_file "${{npz_files[$SLURM_ARRAY_TASK_ID]}}" -npz_base_name "${{npz_base[$SLURM_ARRAY_TASK_ID]}}" -PROJ_DIR "${{PROJ_DIRS[$SLURM_ARRAY_TASK_ID]}}"
""" 

f = open(os.path.join(SIM_DIR, job_file), mode='w')
f.write('%s\n' % job_str)
f.close()

sim_name = 'sim-samp100-T100-sim1000'

sims = []
#dirs = []

for i in range(10):
    sim_out_i = os.path.join(SIM_DIR, sim_name + f'-stochastic-{i}.npz')
    sims.append(sim_out_i)
    #dir_i = os.path.join()

# transfer npz file
for i in sims:
    print(f'scp {i} {SSH_HOME}{SSH_DATA} &&')

#print(f'mkdir {SSH_HOME}{SSH_DATA}/{back_dir_str}_*/)
    

# transfer script

#print(f'scp {script_path} {SSH_HOME}{SSH_DATA} &&')

# transfer job file

job_path = os.path.join(SIM_DIR, job_file)

print(f'scp {job_path} {SSH_HOME}{SSH_DATA}')

print('')

# commands to execute on the cluster

print('sbatch %s' % job_file)
print('')

# %% [markdown]
# <a id_name="8"></a>
# ### large object running, 10000 simulations

# %%
script_file            = 'stochastic-shuffle.py'
script_path            = ppath.join(SIM_DIR, script_file)
script_path_clust      = ppath.join(SSH_DATA, script_file)


job_file         = 'job-shuff-10000.sh'
job_str          = f"""#!/bin/bash -l
#!/bin/bash
#SBATCH --job-name=stochastic-shuffle
#SBATCH --output=stoc-shuff.out
#SBATCH --error=stoc-shuff.err
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=1
#SBATCH --mem=64G
#SBATCH --mail-user={USER_EMAIL}
#SBATCH --mail-type=ALL
#SBATCH --time=2-0

module unload miniconda2
module load miniconda3
conda activate sars-env

export PYTHONUNBUFFERED=1

python {script_file} -npz_file {sim_npz_clust} -npz_base_name {sim_name} -PROJ_DIR {BP_PROJ_DIR}
""" 

f = open(os.path.join(SIM_DIR, job_file), mode='w')
f.write('%s\n' % job_str)
f.close()


# transfer npz file

print(f'scp {sim_npz} {SSH_HOME}{SSH_DATA} &&')

# transfer script

print(f'scp {script_path} {SSH_HOME}{SSH_DATA} &&')

# transfer job file

job_path = os.path.join(SIM_DIR, job_file)

print(f'scp {job_path} {SSH_HOME}{SSH_DATA}')

print('')

# commands to execute on the cluster

print('sbatch %s' % job_file)
print('')

# %% [markdown]
# <a id="9"></a>
# ### local running
# large, not optimized for more than 1000 simulation files
# to do: speed up code for larger objects

# %%
# %run stochastic-reformat -npz_file {sim_npz} -npz_base_name {sim_name} -PROJ_DIR {STOC_LOC}
# Out:
# Simulation: 0	Time taken: 124.504ms
# Simulation: 1	Time taken: 116.282ms
# Simulation: 2	Time taken: 115.541ms
# Simulation: 3	Time taken: 120.890ms
# Simulation: 4	Time taken: 123.110ms
# Simulation: 5	Time taken: 124.987ms
# Simulation: 6	Time taken: 129.596ms
# Simulation: 7	Time taken: 129.969ms
# Simulation: 8	Time taken: 131.553ms
# Simulation: 9	Time taken: 138.648ms
# Simulation: 10	Time taken: 134.168ms
# Simulation: 11	Time taken: 137.995ms
# Simulation: 12	Time taken: 136.160ms
# Simulation: 13	Time taken: 141.598ms
# Simulation: 14	Time taken: 141.017ms
# Simulation: 15	Time taken: 144.093ms
# Simulation: 16	Time taken: 145.589ms
# Simulation: 17	Time taken: 146.257ms
# Simulation: 18	Time taken: 142.678ms
# Simulation: 19	Time taken: 148.905ms
# Simulation: 20	Time taken: 150.880ms
# Simulation: 21	Time taken: 150.084ms
# Simulation: 22	Time taken: 154.483ms
# Simulation: 23	Time taken: 156.113ms
# Simulation: 24	Time taken: 153.676ms
# Simulation: 25	Time taken: 161.389ms
# Simulation: 26	Time taken: 164.114ms
# Simulation: 27	Time taken: 162.205ms
# Simulation: 28	Time taken: 165.621ms
# Simulation: 29	Time taken: 169.392ms
# Simulation: 30	Time taken: 243.388ms
# Simulation: 31	Time taken: 166.769ms
# Simulation: 32	Time taken: 169.351ms
# Simulation: 33	Time taken: 169.370ms
# Simulation: 34	Time taken: 176.005ms
# Simulation: 35	Time taken: 177.468ms
# Simulation: 36	Time taken: 179.610ms
# Simulation: 37	Time taken: 179.130ms
# Simulation: 38	Time taken: 193.475ms
# Simulation: 39	Time taken: 184.365ms
# Simulation: 40	Time taken: 186.360ms
# Simulation: 41	Time taken: 186.607ms
# Simulation: 42	Time taken: 193.665ms
# Simulation: 43	Time taken: 191.782ms
# Simulation: 44	Time taken: 194.641ms
# Simulation: 45	Time taken: 195.770ms
# Simulation: 46	Time taken: 202.294ms
# Simulation: 47	Time taken: 195.934ms
# Simulation: 48	Time taken: 201.749ms
# Simulation: 49	Time taken: 199.222ms
# Simulation: 50	Time taken: 207.444ms
# Simulation: 51	Time taken: 208.199ms
# Simulation: 52	Time taken: 210.341ms
# Simulation: 53	Time taken: 206.631ms
# Simulation: 54	Time taken: 213.933ms
# Simulation: 55	Time taken: 212.114ms
# Simulation: 56	Time taken: 215.553ms
# Simulation: 57	Time taken: 221.696ms
# Simulation: 58	Time taken: 219.488ms
# Simulation: 59	Time taken: 220.733ms
# Simulation: 60	Time taken: 230.338ms
# Simulation: 61	Time taken: 228.378ms
# Simulation: 62	Time taken: 230.826ms
# Simulation: 63	Time taken: 228.137ms
# Simulation: 64	Time taken: 249.066ms
# Simulation: 65	Time taken: 235.141ms
# Simulation: 66	Time taken: 240.695ms
# Simulation: 67	Time taken: 237.252ms
# Simulation: 68	Time taken: 239.368ms
# Simulation: 69	Time taken: 239.933ms
# Simulation: 70	Time taken: 244.103ms
# Simulation: 71	Time taken: 242.186ms
# Simulation: 72	Time taken: 249.151ms
# Simulation: 73	Time taken: 249.854ms
# Simulation: 74	Time taken: 250.274ms
# Simulation: 75	Time taken: 250.019ms
# Simulation: 76	Time taken: 251.948ms
# Simulation: 77	Time taken: 255.972ms
# Simulation: 78	Time taken: 261.447ms
# Simulation: 79	Time taken: 262.470ms
# Simulation: 80	Time taken: 267.556ms
# Simulation: 81	Time taken: 256.959ms
# Simulation: 82	Time taken: 262.650ms
# Simulation: 83	Time taken: 261.086ms
# Simulation: 84	Time taken: 267.008ms
# Simulation: 85	Time taken: 278.913ms
# Simulation: 86	Time taken: 279.872ms
# Simulation: 87	Time taken: 271.128ms
# Simulation: 88	Time taken: 274.272ms
# Simulation: 89	Time taken: 272.930ms
# Simulation: 90	Time taken: 282.062ms
# Simulation: 91	Time taken: 284.242ms
# Simulation: 92	Time taken: 297.931ms
# Simulation: 93	Time taken: 279.432ms
# Simulation: 94	Time taken: 283.795ms
# Simulation: 95	Time taken: 279.034ms
# Simulation: 96	Time taken: 284.687ms
# Simulation: 97	Time taken: 291.212ms
# Simulation: 98	Time taken: 294.644ms
# Simulation: 99	Time taken: 296.452ms
# Saved dataframe_[0] to the df_0_ref sub-directory
# Saved dataframe_[1] to the df_0_ref sub-directory
# Saved dataframe_[2] to the df_0_ref sub-directory
# Saved dataframe_[3] to the df_0_ref sub-directory
# Saved dataframe_[4] to the df_0_ref sub-directory
# Saved dataframe_[5] to the df_0_ref sub-directory
# Saved dataframe_[0] to the df_1_ref sub-directory
# Saved dataframe_[1] to the df_1_ref sub-directory
# Saved dataframe_[2] to the df_1_ref sub-directory
# Saved dataframe_[3] to the df_1_ref sub-directory
# Saved dataframe_[4] to the df_1_ref sub-directory
# Saved dataframe_[5] to the df_1_ref sub-directory
# Saved dataframe_[0] to the df_2_ref sub-directory
# Saved dataframe_[1] to the df_2_ref sub-directory
# Saved dataframe_[2] to the df_2_ref sub-directory
# Saved dataframe_[3] to the df_2_ref sub-directory
# Saved dataframe_[4] to the df_2_ref sub-directory
# Saved dataframe_[5] to the df_2_ref sub-directory
# Saved dataframe_[0] to the df_3_ref sub-directory
# Saved dataframe_[1] to the df_3_ref sub-directory
# Saved dataframe_[2] to the df_3_ref sub-directory
# Saved dataframe_[3] to the df_3_ref sub-directory
# Saved dataframe_[4] to the df_3_ref sub-directory
# Saved dataframe_[5] to the df_3_ref sub-directory
# Saved dataframe_[0] to the df_4_ref sub-directory
# Saved dataframe_[1] to the df_4_ref sub-directory
# Saved dataframe_[2] to the df_4_ref sub-directory
# Saved dataframe_[3] to the df_4_ref sub-directory
# Saved dataframe_[4] to the df_4_ref sub-directory
# Saved dataframe_[5] to the df_4_ref sub-directory
# Saved dataframe_[0] to the df_5_ref sub-directory
# Saved dataframe_[1] to the df_5_ref sub-directory
# Saved dataframe_[2] to the df_5_ref sub-directory
# Saved dataframe_[3] to the df_5_ref sub-directory
# Saved dataframe_[4] to the df_5_ref sub-directory
# Saved dataframe_[5] to the df_5_ref sub-directory
# Saved dataframe_[0] to the df_6_ref sub-directory
# Saved dataframe_[1] to the df_6_ref sub-directory
# Saved dataframe_[2] to the df_6_ref sub-directory
# Saved dataframe_[3] to the df_6_ref sub-directory
# Saved dataframe_[4] to the df_6_ref sub-directory
# Saved dataframe_[5] to the df_6_ref sub-directory
# Saved dataframe_[0] to the df_7_ref sub-directory
# Saved dataframe_[1] to the df_7_ref sub-directory
# Saved dataframe_[2] to the df_7_ref sub-directory
# Saved dataframe_[3] to the df_7_ref sub-directory
# Saved dataframe_[4] to the df_7_ref sub-directory
# Saved dataframe_[5] to the df_7_ref sub-directory
# Saved dataframe_[0] to the df_8_ref sub-directory
# Saved dataframe_[1] to the df_8_ref sub-directory
# Saved dataframe_[2] to the df_8_ref sub-directory
# Saved dataframe_[3] to the df_8_ref sub-directory
# Saved dataframe_[4] to the df_8_ref sub-directory
# Saved dataframe_[5] to the df_8_ref sub-directory
# Saved dataframe_[0] to the df_9_ref sub-directory
# Saved dataframe_[1] to the df_9_ref sub-directory
# Saved dataframe_[2] to the df_9_ref sub-directory
# Saved dataframe_[3] to the df_9_ref sub-directory
# Saved dataframe_[4] to the df_9_ref sub-directory
# Saved dataframe_[5] to the df_9_ref sub-directory
# Saved dataframe_[0] to the df_10_ref sub-directory
# Saved dataframe_[1] to the df_10_ref sub-directory
# Saved dataframe_[2] to the df_10_ref sub-directory
# Saved dataframe_[3] to the df_10_ref sub-directory
# Saved dataframe_[4] to the df_10_ref sub-directory
# Saved dataframe_[5] to the df_10_ref sub-directory
# Saved dataframe_[0] to the df_11_ref sub-directory
# Saved dataframe_[1] to the df_11_ref sub-directory
# Saved dataframe_[2] to the df_11_ref sub-directory
# Saved dataframe_[3] to the df_11_ref sub-directory
# Saved dataframe_[4] to the df_11_ref sub-directory
# Saved dataframe_[5] to the df_11_ref sub-directory
# Saved dataframe_[0] to the df_12_ref sub-directory
# Saved dataframe_[1] to the df_12_ref sub-directory
# Saved dataframe_[2] to the df_12_ref sub-directory
# Saved dataframe_[3] to the df_12_ref sub-directory
# Saved dataframe_[4] to the df_12_ref sub-directory
# Saved dataframe_[5] to the df_12_ref sub-directory
# Saved dataframe_[0] to the df_13_ref sub-directory
# Saved dataframe_[1] to the df_13_ref sub-directory
# Saved dataframe_[2] to the df_13_ref sub-directory
# Saved dataframe_[3] to the df_13_ref sub-directory
# Saved dataframe_[4] to the df_13_ref sub-directory
# Saved dataframe_[5] to the df_13_ref sub-directory
# Saved dataframe_[0] to the df_14_ref sub-directory
# Saved dataframe_[1] to the df_14_ref sub-directory
# Saved dataframe_[2] to the df_14_ref sub-directory
# Saved dataframe_[3] to the df_14_ref sub-directory
# Saved dataframe_[4] to the df_14_ref sub-directory
# Saved dataframe_[5] to the df_14_ref sub-directory
# Saved dataframe_[0] to the df_15_ref sub-directory
# Saved dataframe_[1] to the df_15_ref sub-directory
# Saved dataframe_[2] to the df_15_ref sub-directory
# Saved dataframe_[3] to the df_15_ref sub-directory
# Saved dataframe_[4] to the df_15_ref sub-directory
# Saved dataframe_[5] to the df_15_ref sub-directory
# Saved dataframe_[0] to the df_16_ref sub-directory
# Saved dataframe_[1] to the df_16_ref sub-directory
# Saved dataframe_[2] to the df_16_ref sub-directory
# Saved dataframe_[3] to the df_16_ref sub-directory
# Saved dataframe_[4] to the df_16_ref sub-directory
# Saved dataframe_[5] to the df_16_ref sub-directory
# Saved dataframe_[0] to the df_17_ref sub-directory
# Saved dataframe_[1] to the df_17_ref sub-directory
# Saved dataframe_[2] to the df_17_ref sub-directory
# Saved dataframe_[3] to the df_17_ref sub-directory
# Saved dataframe_[4] to the df_17_ref sub-directory
# Saved dataframe_[5] to the df_17_ref sub-directory
# Saved dataframe_[0] to the df_18_ref sub-directory
# Saved dataframe_[1] to the df_18_ref sub-directory
# Saved dataframe_[2] to the df_18_ref sub-directory
# Saved dataframe_[3] to the df_18_ref sub-directory
# Saved dataframe_[4] to the df_18_ref sub-directory
# Saved dataframe_[5] to the df_18_ref sub-directory
# Saved dataframe_[0] to the df_19_ref sub-directory
# Saved dataframe_[1] to the df_19_ref sub-directory
# Saved dataframe_[2] to the df_19_ref sub-directory
# Saved dataframe_[3] to the df_19_ref sub-directory
# Saved dataframe_[4] to the df_19_ref sub-directory
# Saved dataframe_[5] to the df_19_ref sub-directory
# Saved dataframe_[0] to the df_20_ref sub-directory
# Saved dataframe_[1] to the df_20_ref sub-directory
# Saved dataframe_[2] to the df_20_ref sub-directory
# Saved dataframe_[3] to the df_20_ref sub-directory
# Saved dataframe_[4] to the df_20_ref sub-directory
# Saved dataframe_[5] to the df_20_ref sub-directory
# Saved dataframe_[0] to the df_21_ref sub-directory
# Saved dataframe_[1] to the df_21_ref sub-directory
# Saved dataframe_[2] to the df_21_ref sub-directory
# Saved dataframe_[3] to the df_21_ref sub-directory
# Saved dataframe_[4] to the df_21_ref sub-directory
# Saved dataframe_[5] to the df_21_ref sub-directory
# Saved dataframe_[0] to the df_22_ref sub-directory
# Saved dataframe_[1] to the df_22_ref sub-directory
# Saved dataframe_[2] to the df_22_ref sub-directory
# Saved dataframe_[3] to the df_22_ref sub-directory
# Saved dataframe_[4] to the df_22_ref sub-directory
# Saved dataframe_[5] to the df_22_ref sub-directory
# Saved dataframe_[0] to the df_23_ref sub-directory
# Saved dataframe_[1] to the df_23_ref sub-directory
# Saved dataframe_[2] to the df_23_ref sub-directory
# Saved dataframe_[3] to the df_23_ref sub-directory
# Saved dataframe_[4] to the df_23_ref sub-directory
# Saved dataframe_[5] to the df_23_ref sub-directory
# Saved dataframe_[0] to the df_24_ref sub-directory
# Saved dataframe_[1] to the df_24_ref sub-directory
# Saved dataframe_[2] to the df_24_ref sub-directory
# Saved dataframe_[3] to the df_24_ref sub-directory
# Saved dataframe_[4] to the df_24_ref sub-directory
# Saved dataframe_[5] to the df_24_ref sub-directory
# Saved dataframe_[0] to the df_25_ref sub-directory
# Saved dataframe_[1] to the df_25_ref sub-directory
# Saved dataframe_[2] to the df_25_ref sub-directory
# Saved dataframe_[3] to the df_25_ref sub-directory
# Saved dataframe_[4] to the df_25_ref sub-directory
# Saved dataframe_[5] to the df_25_ref sub-directory
# Saved dataframe_[0] to the df_26_ref sub-directory
# Saved dataframe_[1] to the df_26_ref sub-directory
# Saved dataframe_[2] to the df_26_ref sub-directory
# Saved dataframe_[3] to the df_26_ref sub-directory
# Saved dataframe_[4] to the df_26_ref sub-directory
# Saved dataframe_[5] to the df_26_ref sub-directory
# Saved dataframe_[0] to the df_27_ref sub-directory
# Saved dataframe_[1] to the df_27_ref sub-directory
# Saved dataframe_[2] to the df_27_ref sub-directory
# Saved dataframe_[3] to the df_27_ref sub-directory
# Saved dataframe_[4] to the df_27_ref sub-directory
# Saved dataframe_[5] to the df_27_ref sub-directory
# Saved dataframe_[0] to the df_28_ref sub-directory
# Saved dataframe_[1] to the df_28_ref sub-directory
# Saved dataframe_[2] to the df_28_ref sub-directory
# Saved dataframe_[3] to the df_28_ref sub-directory
# Saved dataframe_[4] to the df_28_ref sub-directory
# Saved dataframe_[5] to the df_28_ref sub-directory
# Saved dataframe_[0] to the df_29_ref sub-directory
# Saved dataframe_[1] to the df_29_ref sub-directory
# Saved dataframe_[2] to the df_29_ref sub-directory
# Saved dataframe_[3] to the df_29_ref sub-directory
# Saved dataframe_[4] to the df_29_ref sub-directory
# Saved dataframe_[5] to the df_29_ref sub-directory
# Saved dataframe_[0] to the df_30_ref sub-directory
# Saved dataframe_[1] to the df_30_ref sub-directory
# Saved dataframe_[2] to the df_30_ref sub-directory
# Saved dataframe_[3] to the df_30_ref sub-directory
# Saved dataframe_[4] to the df_30_ref sub-directory
# Saved dataframe_[5] to the df_30_ref sub-directory
# Saved dataframe_[0] to the df_31_ref sub-directory
# Saved dataframe_[1] to the df_31_ref sub-directory
# Saved dataframe_[2] to the df_31_ref sub-directory
# Saved dataframe_[3] to the df_31_ref sub-directory
# Saved dataframe_[4] to the df_31_ref sub-directory
# Saved dataframe_[5] to the df_31_ref sub-directory
# Saved dataframe_[0] to the df_32_ref sub-directory
# Saved dataframe_[1] to the df_32_ref sub-directory
# Saved dataframe_[2] to the df_32_ref sub-directory
# Saved dataframe_[3] to the df_32_ref sub-directory
# Saved dataframe_[4] to the df_32_ref sub-directory
# Saved dataframe_[5] to the df_32_ref sub-directory
# Saved dataframe_[0] to the df_33_ref sub-directory
# Saved dataframe_[1] to the df_33_ref sub-directory
# Saved dataframe_[2] to the df_33_ref sub-directory
# Saved dataframe_[3] to the df_33_ref sub-directory
# Saved dataframe_[4] to the df_33_ref sub-directory
# Saved dataframe_[5] to the df_33_ref sub-directory
# Saved dataframe_[0] to the df_34_ref sub-directory
# Saved dataframe_[1] to the df_34_ref sub-directory
# Saved dataframe_[2] to the df_34_ref sub-directory
# Saved dataframe_[3] to the df_34_ref sub-directory
# Saved dataframe_[4] to the df_34_ref sub-directory
# Saved dataframe_[5] to the df_34_ref sub-directory
# Saved dataframe_[0] to the df_35_ref sub-directory
# Saved dataframe_[1] to the df_35_ref sub-directory
# Saved dataframe_[2] to the df_35_ref sub-directory
# Saved dataframe_[3] to the df_35_ref sub-directory
# Saved dataframe_[4] to the df_35_ref sub-directory
# Saved dataframe_[5] to the df_35_ref sub-directory
# Saved dataframe_[0] to the df_36_ref sub-directory
# Saved dataframe_[1] to the df_36_ref sub-directory
# Saved dataframe_[2] to the df_36_ref sub-directory
# Saved dataframe_[3] to the df_36_ref sub-directory
# Saved dataframe_[4] to the df_36_ref sub-directory
# Saved dataframe_[5] to the df_36_ref sub-directory
# Saved dataframe_[0] to the df_37_ref sub-directory
# Saved dataframe_[1] to the df_37_ref sub-directory
# Saved dataframe_[2] to the df_37_ref sub-directory
# Saved dataframe_[3] to the df_37_ref sub-directory
# Saved dataframe_[4] to the df_37_ref sub-directory
# Saved dataframe_[5] to the df_37_ref sub-directory
# Saved dataframe_[0] to the df_38_ref sub-directory
# Saved dataframe_[1] to the df_38_ref sub-directory
# Saved dataframe_[2] to the df_38_ref sub-directory
# Saved dataframe_[3] to the df_38_ref sub-directory
# Saved dataframe_[4] to the df_38_ref sub-directory
# Saved dataframe_[5] to the df_38_ref sub-directory
# Saved dataframe_[0] to the df_39_ref sub-directory
# Saved dataframe_[1] to the df_39_ref sub-directory
# Saved dataframe_[2] to the df_39_ref sub-directory
# Saved dataframe_[3] to the df_39_ref sub-directory
# Saved dataframe_[4] to the df_39_ref sub-directory
# Saved dataframe_[5] to the df_39_ref sub-directory
# Saved dataframe_[0] to the df_40_ref sub-directory
# Saved dataframe_[1] to the df_40_ref sub-directory
# Saved dataframe_[2] to the df_40_ref sub-directory
# Saved dataframe_[3] to the df_40_ref sub-directory
# Saved dataframe_[4] to the df_40_ref sub-directory
# Saved dataframe_[5] to the df_40_ref sub-directory
# Saved dataframe_[0] to the df_41_ref sub-directory
# Saved dataframe_[1] to the df_41_ref sub-directory
# Saved dataframe_[2] to the df_41_ref sub-directory
# Saved dataframe_[3] to the df_41_ref sub-directory
# Saved dataframe_[4] to the df_41_ref sub-directory
# Saved dataframe_[5] to the df_41_ref sub-directory
# Saved dataframe_[0] to the df_42_ref sub-directory
# Saved dataframe_[1] to the df_42_ref sub-directory
# Saved dataframe_[2] to the df_42_ref sub-directory
# Saved dataframe_[3] to the df_42_ref sub-directory
# Saved dataframe_[4] to the df_42_ref sub-directory
# Saved dataframe_[5] to the df_42_ref sub-directory
# Saved dataframe_[0] to the df_43_ref sub-directory
# Saved dataframe_[1] to the df_43_ref sub-directory
# Saved dataframe_[2] to the df_43_ref sub-directory
# Saved dataframe_[3] to the df_43_ref sub-directory
# Saved dataframe_[4] to the df_43_ref sub-directory
# Saved dataframe_[5] to the df_43_ref sub-directory
# Saved dataframe_[0] to the df_44_ref sub-directory
# Saved dataframe_[1] to the df_44_ref sub-directory
# Saved dataframe_[2] to the df_44_ref sub-directory
# Saved dataframe_[3] to the df_44_ref sub-directory
# Saved dataframe_[4] to the df_44_ref sub-directory
# Saved dataframe_[5] to the df_44_ref sub-directory
# Saved dataframe_[0] to the df_45_ref sub-directory
# Saved dataframe_[1] to the df_45_ref sub-directory
# Saved dataframe_[2] to the df_45_ref sub-directory
# Saved dataframe_[3] to the df_45_ref sub-directory
# Saved dataframe_[4] to the df_45_ref sub-directory
# Saved dataframe_[5] to the df_45_ref sub-directory
# Saved dataframe_[0] to the df_46_ref sub-directory
# Saved dataframe_[1] to the df_46_ref sub-directory
# Saved dataframe_[2] to the df_46_ref sub-directory
# Saved dataframe_[3] to the df_46_ref sub-directory
# Saved dataframe_[4] to the df_46_ref sub-directory
# Saved dataframe_[5] to the df_46_ref sub-directory
# Saved dataframe_[0] to the df_47_ref sub-directory
# Saved dataframe_[1] to the df_47_ref sub-directory
# Saved dataframe_[2] to the df_47_ref sub-directory
# Saved dataframe_[3] to the df_47_ref sub-directory
# Saved dataframe_[4] to the df_47_ref sub-directory
# Saved dataframe_[5] to the df_47_ref sub-directory
# Saved dataframe_[0] to the df_48_ref sub-directory
# Saved dataframe_[1] to the df_48_ref sub-directory
# Saved dataframe_[2] to the df_48_ref sub-directory
# Saved dataframe_[3] to the df_48_ref sub-directory
# Saved dataframe_[4] to the df_48_ref sub-directory
# Saved dataframe_[5] to the df_48_ref sub-directory
# Saved dataframe_[0] to the df_49_ref sub-directory
# Saved dataframe_[1] to the df_49_ref sub-directory
# Saved dataframe_[2] to the df_49_ref sub-directory
# Saved dataframe_[3] to the df_49_ref sub-directory
# Saved dataframe_[4] to the df_49_ref sub-directory
# Saved dataframe_[5] to the df_49_ref sub-directory
# Saved dataframe_[0] to the df_50_ref sub-directory
# Saved dataframe_[1] to the df_50_ref sub-directory
# Saved dataframe_[2] to the df_50_ref sub-directory
# Saved dataframe_[3] to the df_50_ref sub-directory
# Saved dataframe_[4] to the df_50_ref sub-directory
# Saved dataframe_[5] to the df_50_ref sub-directory
# Saved dataframe_[0] to the df_51_ref sub-directory
# Saved dataframe_[1] to the df_51_ref sub-directory
# Saved dataframe_[2] to the df_51_ref sub-directory
# Saved dataframe_[3] to the df_51_ref sub-directory
# Saved dataframe_[4] to the df_51_ref sub-directory
# Saved dataframe_[5] to the df_51_ref sub-directory
# Saved dataframe_[0] to the df_52_ref sub-directory
# Saved dataframe_[1] to the df_52_ref sub-directory
# Saved dataframe_[2] to the df_52_ref sub-directory
# Saved dataframe_[3] to the df_52_ref sub-directory
# Saved dataframe_[4] to the df_52_ref sub-directory
# Saved dataframe_[5] to the df_52_ref sub-directory
# Saved dataframe_[0] to the df_53_ref sub-directory
# Saved dataframe_[1] to the df_53_ref sub-directory
# Saved dataframe_[2] to the df_53_ref sub-directory
# Saved dataframe_[3] to the df_53_ref sub-directory
# Saved dataframe_[4] to the df_53_ref sub-directory
# Saved dataframe_[5] to the df_53_ref sub-directory
# Saved dataframe_[0] to the df_54_ref sub-directory
# Saved dataframe_[1] to the df_54_ref sub-directory
# Saved dataframe_[2] to the df_54_ref sub-directory
# Saved dataframe_[3] to the df_54_ref sub-directory
# Saved dataframe_[4] to the df_54_ref sub-directory
# Saved dataframe_[5] to the df_54_ref sub-directory
# Saved dataframe_[0] to the df_55_ref sub-directory
# Saved dataframe_[1] to the df_55_ref sub-directory
# Saved dataframe_[2] to the df_55_ref sub-directory
# Saved dataframe_[3] to the df_55_ref sub-directory
# Saved dataframe_[4] to the df_55_ref sub-directory
# Saved dataframe_[5] to the df_55_ref sub-directory
# Saved dataframe_[0] to the df_56_ref sub-directory
# Saved dataframe_[1] to the df_56_ref sub-directory
# Saved dataframe_[2] to the df_56_ref sub-directory
# Saved dataframe_[3] to the df_56_ref sub-directory
# Saved dataframe_[4] to the df_56_ref sub-directory
# Saved dataframe_[5] to the df_56_ref sub-directory
# Saved dataframe_[0] to the df_57_ref sub-directory
# Saved dataframe_[1] to the df_57_ref sub-directory
# Saved dataframe_[2] to the df_57_ref sub-directory
# Saved dataframe_[3] to the df_57_ref sub-directory
# Saved dataframe_[4] to the df_57_ref sub-directory
# Saved dataframe_[5] to the df_57_ref sub-directory
# Saved dataframe_[0] to the df_58_ref sub-directory
# Saved dataframe_[1] to the df_58_ref sub-directory
# Saved dataframe_[2] to the df_58_ref sub-directory
# Saved dataframe_[3] to the df_58_ref sub-directory
# Saved dataframe_[4] to the df_58_ref sub-directory
# Saved dataframe_[5] to the df_58_ref sub-directory
# Saved dataframe_[0] to the df_59_ref sub-directory
# Saved dataframe_[1] to the df_59_ref sub-directory
# Saved dataframe_[2] to the df_59_ref sub-directory
# Saved dataframe_[3] to the df_59_ref sub-directory
# Saved dataframe_[4] to the df_59_ref sub-directory
# Saved dataframe_[5] to the df_59_ref sub-directory
# Saved dataframe_[0] to the df_60_ref sub-directory
# Saved dataframe_[1] to the df_60_ref sub-directory
# Saved dataframe_[2] to the df_60_ref sub-directory
# Saved dataframe_[3] to the df_60_ref sub-directory
# Saved dataframe_[4] to the df_60_ref sub-directory
# Saved dataframe_[5] to the df_60_ref sub-directory
# Saved dataframe_[0] to the df_61_ref sub-directory
# Saved dataframe_[1] to the df_61_ref sub-directory
# Saved dataframe_[2] to the df_61_ref sub-directory
# Saved dataframe_[3] to the df_61_ref sub-directory
# Saved dataframe_[4] to the df_61_ref sub-directory
# Saved dataframe_[5] to the df_61_ref sub-directory
# Saved dataframe_[0] to the df_62_ref sub-directory
# Saved dataframe_[1] to the df_62_ref sub-directory
# Saved dataframe_[2] to the df_62_ref sub-directory
# Saved dataframe_[3] to the df_62_ref sub-directory
# Saved dataframe_[4] to the df_62_ref sub-directory
# Saved dataframe_[5] to the df_62_ref sub-directory
# Saved dataframe_[0] to the df_63_ref sub-directory
# Saved dataframe_[1] to the df_63_ref sub-directory
# Saved dataframe_[2] to the df_63_ref sub-directory
# Saved dataframe_[3] to the df_63_ref sub-directory
# Saved dataframe_[4] to the df_63_ref sub-directory
# Saved dataframe_[5] to the df_63_ref sub-directory
# Saved dataframe_[0] to the df_64_ref sub-directory
# Saved dataframe_[1] to the df_64_ref sub-directory
# Saved dataframe_[2] to the df_64_ref sub-directory
# Saved dataframe_[3] to the df_64_ref sub-directory
# Saved dataframe_[4] to the df_64_ref sub-directory
# Saved dataframe_[5] to the df_64_ref sub-directory
# Saved dataframe_[0] to the df_65_ref sub-directory
# Saved dataframe_[1] to the df_65_ref sub-directory
# Saved dataframe_[2] to the df_65_ref sub-directory
# Saved dataframe_[3] to the df_65_ref sub-directory
# Saved dataframe_[4] to the df_65_ref sub-directory
# Saved dataframe_[5] to the df_65_ref sub-directory
# Saved dataframe_[0] to the df_66_ref sub-directory
# Saved dataframe_[1] to the df_66_ref sub-directory
# Saved dataframe_[2] to the df_66_ref sub-directory
# Saved dataframe_[3] to the df_66_ref sub-directory
# Saved dataframe_[4] to the df_66_ref sub-directory
# Saved dataframe_[5] to the df_66_ref sub-directory
# Saved dataframe_[0] to the df_67_ref sub-directory
# Saved dataframe_[1] to the df_67_ref sub-directory
# Saved dataframe_[2] to the df_67_ref sub-directory
# Saved dataframe_[3] to the df_67_ref sub-directory
# Saved dataframe_[4] to the df_67_ref sub-directory
# Saved dataframe_[5] to the df_67_ref sub-directory
# Saved dataframe_[0] to the df_68_ref sub-directory
# Saved dataframe_[1] to the df_68_ref sub-directory
# Saved dataframe_[2] to the df_68_ref sub-directory
# Saved dataframe_[3] to the df_68_ref sub-directory
# Saved dataframe_[4] to the df_68_ref sub-directory
# Saved dataframe_[5] to the df_68_ref sub-directory
# Saved dataframe_[0] to the df_69_ref sub-directory
# Saved dataframe_[1] to the df_69_ref sub-directory
# Saved dataframe_[2] to the df_69_ref sub-directory
# Saved dataframe_[3] to the df_69_ref sub-directory
# Saved dataframe_[4] to the df_69_ref sub-directory
# Saved dataframe_[5] to the df_69_ref sub-directory
# Saved dataframe_[0] to the df_70_ref sub-directory
# Saved dataframe_[1] to the df_70_ref sub-directory
# Saved dataframe_[2] to the df_70_ref sub-directory
# Saved dataframe_[3] to the df_70_ref sub-directory
# Saved dataframe_[4] to the df_70_ref sub-directory
# Saved dataframe_[5] to the df_70_ref sub-directory
# Saved dataframe_[0] to the df_71_ref sub-directory
# Saved dataframe_[1] to the df_71_ref sub-directory
# Saved dataframe_[2] to the df_71_ref sub-directory
# Saved dataframe_[3] to the df_71_ref sub-directory
# Saved dataframe_[4] to the df_71_ref sub-directory
# Saved dataframe_[5] to the df_71_ref sub-directory
# Saved dataframe_[0] to the df_72_ref sub-directory
# Saved dataframe_[1] to the df_72_ref sub-directory
# Saved dataframe_[2] to the df_72_ref sub-directory
# Saved dataframe_[3] to the df_72_ref sub-directory
# Saved dataframe_[4] to the df_72_ref sub-directory
# Saved dataframe_[5] to the df_72_ref sub-directory
# Saved dataframe_[0] to the df_73_ref sub-directory
# Saved dataframe_[1] to the df_73_ref sub-directory
# Saved dataframe_[2] to the df_73_ref sub-directory
# Saved dataframe_[3] to the df_73_ref sub-directory
# Saved dataframe_[4] to the df_73_ref sub-directory
# Saved dataframe_[5] to the df_73_ref sub-directory
# Saved dataframe_[0] to the df_74_ref sub-directory
# Saved dataframe_[1] to the df_74_ref sub-directory
# Saved dataframe_[2] to the df_74_ref sub-directory
# Saved dataframe_[3] to the df_74_ref sub-directory
# Saved dataframe_[4] to the df_74_ref sub-directory
# Saved dataframe_[5] to the df_74_ref sub-directory
# Saved dataframe_[0] to the df_75_ref sub-directory
# Saved dataframe_[1] to the df_75_ref sub-directory
# Saved dataframe_[2] to the df_75_ref sub-directory
# Saved dataframe_[3] to the df_75_ref sub-directory
# Saved dataframe_[4] to the df_75_ref sub-directory
# Saved dataframe_[5] to the df_75_ref sub-directory
# Saved dataframe_[0] to the df_76_ref sub-directory
# Saved dataframe_[1] to the df_76_ref sub-directory
# Saved dataframe_[2] to the df_76_ref sub-directory
# Saved dataframe_[3] to the df_76_ref sub-directory
# Saved dataframe_[4] to the df_76_ref sub-directory
# Saved dataframe_[5] to the df_76_ref sub-directory
# Saved dataframe_[0] to the df_77_ref sub-directory
# Saved dataframe_[1] to the df_77_ref sub-directory
# Saved dataframe_[2] to the df_77_ref sub-directory
# Saved dataframe_[3] to the df_77_ref sub-directory
# Saved dataframe_[4] to the df_77_ref sub-directory
# Saved dataframe_[5] to the df_77_ref sub-directory
# Saved dataframe_[0] to the df_78_ref sub-directory
# Saved dataframe_[1] to the df_78_ref sub-directory
# Saved dataframe_[2] to the df_78_ref sub-directory
# Saved dataframe_[3] to the df_78_ref sub-directory
# Saved dataframe_[4] to the df_78_ref sub-directory
# Saved dataframe_[5] to the df_78_ref sub-directory
# Saved dataframe_[0] to the df_79_ref sub-directory
# Saved dataframe_[1] to the df_79_ref sub-directory
# Saved dataframe_[2] to the df_79_ref sub-directory
# Saved dataframe_[3] to the df_79_ref sub-directory
# Saved dataframe_[4] to the df_79_ref sub-directory
# Saved dataframe_[5] to the df_79_ref sub-directory
# Saved dataframe_[0] to the df_80_ref sub-directory
# Saved dataframe_[1] to the df_80_ref sub-directory
# Saved dataframe_[2] to the df_80_ref sub-directory
# Saved dataframe_[3] to the df_80_ref sub-directory
# Saved dataframe_[4] to the df_80_ref sub-directory
# Saved dataframe_[5] to the df_80_ref sub-directory
# Saved dataframe_[0] to the df_81_ref sub-directory
# Saved dataframe_[1] to the df_81_ref sub-directory
# Saved dataframe_[2] to the df_81_ref sub-directory
# Saved dataframe_[3] to the df_81_ref sub-directory
# Saved dataframe_[4] to the df_81_ref sub-directory
# Saved dataframe_[5] to the df_81_ref sub-directory
# Saved dataframe_[0] to the df_82_ref sub-directory
# Saved dataframe_[1] to the df_82_ref sub-directory
# Saved dataframe_[2] to the df_82_ref sub-directory
# Saved dataframe_[3] to the df_82_ref sub-directory
# Saved dataframe_[4] to the df_82_ref sub-directory
# Saved dataframe_[5] to the df_82_ref sub-directory
# Saved dataframe_[0] to the df_83_ref sub-directory
# Saved dataframe_[1] to the df_83_ref sub-directory
# Saved dataframe_[2] to the df_83_ref sub-directory
# Saved dataframe_[3] to the df_83_ref sub-directory
# Saved dataframe_[4] to the df_83_ref sub-directory
# Saved dataframe_[5] to the df_83_ref sub-directory
# Saved dataframe_[0] to the df_84_ref sub-directory
# Saved dataframe_[1] to the df_84_ref sub-directory
# Saved dataframe_[2] to the df_84_ref sub-directory
# Saved dataframe_[3] to the df_84_ref sub-directory
# Saved dataframe_[4] to the df_84_ref sub-directory
# Saved dataframe_[5] to the df_84_ref sub-directory
# Saved dataframe_[0] to the df_85_ref sub-directory
# Saved dataframe_[1] to the df_85_ref sub-directory
# Saved dataframe_[2] to the df_85_ref sub-directory
# Saved dataframe_[3] to the df_85_ref sub-directory
# Saved dataframe_[4] to the df_85_ref sub-directory
# Saved dataframe_[5] to the df_85_ref sub-directory
# Saved dataframe_[0] to the df_86_ref sub-directory
# Saved dataframe_[1] to the df_86_ref sub-directory
# Saved dataframe_[2] to the df_86_ref sub-directory
# Saved dataframe_[3] to the df_86_ref sub-directory
# Saved dataframe_[4] to the df_86_ref sub-directory
# Saved dataframe_[5] to the df_86_ref sub-directory
# Saved dataframe_[0] to the df_87_ref sub-directory
# Saved dataframe_[1] to the df_87_ref sub-directory
# Saved dataframe_[2] to the df_87_ref sub-directory
# Saved dataframe_[3] to the df_87_ref sub-directory
# Saved dataframe_[4] to the df_87_ref sub-directory
# Saved dataframe_[5] to the df_87_ref sub-directory
# Saved dataframe_[0] to the df_88_ref sub-directory
# Saved dataframe_[1] to the df_88_ref sub-directory
# Saved dataframe_[2] to the df_88_ref sub-directory
# Saved dataframe_[3] to the df_88_ref sub-directory
# Saved dataframe_[4] to the df_88_ref sub-directory
# Saved dataframe_[5] to the df_88_ref sub-directory
# Saved dataframe_[0] to the df_89_ref sub-directory
# Saved dataframe_[1] to the df_89_ref sub-directory
# Saved dataframe_[2] to the df_89_ref sub-directory
# Saved dataframe_[3] to the df_89_ref sub-directory
# Saved dataframe_[4] to the df_89_ref sub-directory
# Saved dataframe_[5] to the df_89_ref sub-directory
# Saved dataframe_[0] to the df_90_ref sub-directory
# Saved dataframe_[1] to the df_90_ref sub-directory
# Saved dataframe_[2] to the df_90_ref sub-directory
# Saved dataframe_[3] to the df_90_ref sub-directory
# Saved dataframe_[4] to the df_90_ref sub-directory
# Saved dataframe_[5] to the df_90_ref sub-directory
# Saved dataframe_[0] to the df_91_ref sub-directory
# Saved dataframe_[1] to the df_91_ref sub-directory
# Saved dataframe_[2] to the df_91_ref sub-directory
# Saved dataframe_[3] to the df_91_ref sub-directory
# Saved dataframe_[4] to the df_91_ref sub-directory
# Saved dataframe_[5] to the df_91_ref sub-directory
# Saved dataframe_[0] to the df_92_ref sub-directory
# Saved dataframe_[1] to the df_92_ref sub-directory
# Saved dataframe_[2] to the df_92_ref sub-directory
# Saved dataframe_[3] to the df_92_ref sub-directory
# Saved dataframe_[4] to the df_92_ref sub-directory
# Saved dataframe_[5] to the df_92_ref sub-directory
# Saved dataframe_[0] to the df_93_ref sub-directory
# Saved dataframe_[1] to the df_93_ref sub-directory
# Saved dataframe_[2] to the df_93_ref sub-directory
# Saved dataframe_[3] to the df_93_ref sub-directory
# Saved dataframe_[4] to the df_93_ref sub-directory
# Saved dataframe_[5] to the df_93_ref sub-directory
# Saved dataframe_[0] to the df_94_ref sub-directory
# Saved dataframe_[1] to the df_94_ref sub-directory
# Saved dataframe_[2] to the df_94_ref sub-directory
# Saved dataframe_[3] to the df_94_ref sub-directory
# Saved dataframe_[4] to the df_94_ref sub-directory
# Saved dataframe_[5] to the df_94_ref sub-directory
# Saved dataframe_[0] to the df_95_ref sub-directory
# Saved dataframe_[1] to the df_95_ref sub-directory
# Saved dataframe_[2] to the df_95_ref sub-directory
# Saved dataframe_[3] to the df_95_ref sub-directory
# Saved dataframe_[4] to the df_95_ref sub-directory
# Saved dataframe_[5] to the df_95_ref sub-directory
# Saved dataframe_[0] to the df_96_ref sub-directory
# Saved dataframe_[1] to the df_96_ref sub-directory
# Saved dataframe_[2] to the df_96_ref sub-directory
# Saved dataframe_[3] to the df_96_ref sub-directory
# Saved dataframe_[4] to the df_96_ref sub-directory
# Saved dataframe_[5] to the df_96_ref sub-directory
# Saved dataframe_[0] to the df_97_ref sub-directory
# Saved dataframe_[1] to the df_97_ref sub-directory
# Saved dataframe_[2] to the df_97_ref sub-directory
# Saved dataframe_[3] to the df_97_ref sub-directory
# Saved dataframe_[4] to the df_97_ref sub-directory
# Saved dataframe_[5] to the df_97_ref sub-directory
# Saved dataframe_[0] to the df_98_ref sub-directory
# Saved dataframe_[1] to the df_98_ref sub-directory
# Saved dataframe_[2] to the df_98_ref sub-directory
# Saved dataframe_[3] to the df_98_ref sub-directory
# Saved dataframe_[4] to the df_98_ref sub-directory
# Saved dataframe_[5] to the df_98_ref sub-directory
# Saved dataframe_[0] to the df_99_ref sub-directory
# Saved dataframe_[1] to the df_99_ref sub-directory
# Saved dataframe_[2] to the df_99_ref sub-directory
# Saved dataframe_[3] to the df_99_ref sub-directory
# Saved dataframe_[4] to the df_99_ref sub-directory
# Saved dataframe_[5] to the df_99_ref sub-directory

# %%
# %run stochastic-shuffle -npz_file {sim_npz} -npz_base_name {sim_name} -PROJ_DIR {BP_LOC_DIR}
# Out:
# Simulation: 0	Time taken: 238.277ms
# Simulation: 1	Time taken: 228.576ms
# Simulation: 2	Time taken: 229.582ms
# Simulation: 3	Time taken: 232.523ms
# Simulation: 4	Time taken: 235.248ms
# Simulation: 5	Time taken: 236.998ms
# Simulation: 6	Time taken: 237.149ms
# Simulation: 7	Time taken: 239.234ms
# Simulation: 8	Time taken: 242.174ms
# Simulation: 9	Time taken: 243.788ms
# Simulation: 10	Time taken: 244.645ms
# Simulation: 11	Time taken: 246.423ms
# Simulation: 12	Time taken: 250.645ms
# Simulation: 13	Time taken: 253.553ms
# Simulation: 14	Time taken: 252.557ms
# Simulation: 15	Time taken: 255.792ms
# Simulation: 16	Time taken: 259.693ms
# Simulation: 17	Time taken: 261.264ms
# Simulation: 18	Time taken: 262.495ms
# Simulation: 19	Time taken: 264.617ms
# Simulation: 20	Time taken: 265.426ms
# Simulation: 21	Time taken: 274.008ms
# Simulation: 22	Time taken: 268.800ms
# Simulation: 23	Time taken: 274.131ms
# Simulation: 24	Time taken: 274.968ms
# Simulation: 25	Time taken: 278.865ms
# Simulation: 26	Time taken: 278.090ms
# Simulation: 27	Time taken: 282.467ms
# Simulation: 28	Time taken: 282.990ms
# Simulation: 29	Time taken: 286.785ms
# Simulation: 30	Time taken: 289.631ms
# Simulation: 31	Time taken: 295.092ms
# Simulation: 32	Time taken: 292.925ms
# Simulation: 33	Time taken: 297.441ms
# Simulation: 34	Time taken: 298.090ms
# Simulation: 35	Time taken: 298.672ms
# Simulation: 36	Time taken: 304.300ms
# Simulation: 37	Time taken: 310.419ms
# Simulation: 38	Time taken: 304.659ms
# Simulation: 39	Time taken: 311.823ms
# Simulation: 40	Time taken: 311.764ms
# Simulation: 41	Time taken: 316.724ms
# Simulation: 42	Time taken: 318.904ms
# Simulation: 43	Time taken: 317.790ms
# Simulation: 44	Time taken: 319.841ms
# Simulation: 45	Time taken: 322.085ms
# Simulation: 46	Time taken: 320.211ms
# Simulation: 47	Time taken: 325.416ms
# Simulation: 48	Time taken: 337.109ms
# Simulation: 49	Time taken: 333.517ms
# Simulation: 50	Time taken: 361.145ms
# Simulation: 51	Time taken: 345.753ms
# Simulation: 52	Time taken: 363.827ms
# Simulation: 53	Time taken: 360.111ms
# Simulation: 54	Time taken: 341.854ms
# Simulation: 55	Time taken: 341.423ms
# Simulation: 56	Time taken: 347.828ms
# Simulation: 57	Time taken: 349.874ms
# Simulation: 58	Time taken: 347.786ms
# Simulation: 59	Time taken: 366.428ms
# Simulation: 60	Time taken: 353.453ms
# Simulation: 61	Time taken: 356.100ms
# Simulation: 62	Time taken: 359.758ms
# Simulation: 63	Time taken: 359.613ms
# Simulation: 64	Time taken: 384.444ms
# Simulation: 65	Time taken: 398.492ms
# Simulation: 66	Time taken: 372.413ms
# Simulation: 67	Time taken: 369.041ms
# Simulation: 68	Time taken: 374.513ms
# Simulation: 69	Time taken: 375.959ms
# Simulation: 70	Time taken: 374.606ms
# Simulation: 71	Time taken: 384.992ms
# Simulation: 72	Time taken: 382.224ms
# Simulation: 73	Time taken: 385.206ms
# Simulation: 74	Time taken: 388.513ms
# Simulation: 75	Time taken: 392.581ms
# Simulation: 76	Time taken: 393.036ms
# Simulation: 77	Time taken: 391.494ms
# Simulation: 78	Time taken: 396.677ms
# Simulation: 79	Time taken: 406.738ms
# Simulation: 80	Time taken: 403.931ms
# Simulation: 81	Time taken: 405.307ms
# Simulation: 82	Time taken: 407.404ms
# Simulation: 83	Time taken: 405.359ms
# Simulation: 84	Time taken: 442.495ms
# Simulation: 85	Time taken: 417.522ms
# Simulation: 86	Time taken: 416.440ms
# Simulation: 87	Time taken: 418.797ms
# Simulation: 88	Time taken: 422.988ms
# Simulation: 89	Time taken: 425.800ms
# Simulation: 90	Time taken: 421.144ms
# Simulation: 91	Time taken: 433.162ms
# Simulation: 92	Time taken: 443.630ms
# Simulation: 93	Time taken: 455.623ms
# Simulation: 94	Time taken: 436.566ms
# Simulation: 95	Time taken: 445.172ms
# Simulation: 96	Time taken: 440.289ms
# Simulation: 97	Time taken: 436.083ms
# Simulation: 98	Time taken: 442.475ms
# Simulation: 99	Time taken: 445.741ms
# Saved dataframe_[3] to the df_0 sub-directory
# Saved dataframe_[0] to the df_0 sub-directory
# Saved dataframe_[1] to the df_0 sub-directory
# Saved dataframe_[2] to the df_0 sub-directory
# Saved dataframe_[5] to the df_0 sub-directory
# Saved dataframe_[4] to the df_0 sub-directory
# Saved dataframe_[0] to the df_1 sub-directory
# Saved dataframe_[4] to the df_1 sub-directory
# Saved dataframe_[5] to the df_1 sub-directory
# Saved dataframe_[1] to the df_1 sub-directory
# Saved dataframe_[3] to the df_1 sub-directory
# Saved dataframe_[2] to the df_1 sub-directory
# Saved dataframe_[2] to the df_2 sub-directory
# Saved dataframe_[5] to the df_2 sub-directory
# Saved dataframe_[0] to the df_2 sub-directory
# Saved dataframe_[1] to the df_2 sub-directory
# Saved dataframe_[3] to the df_2 sub-directory
# Saved dataframe_[4] to the df_2 sub-directory
# Saved dataframe_[2] to the df_3 sub-directory
# Saved dataframe_[1] to the df_3 sub-directory
# Saved dataframe_[3] to the df_3 sub-directory
# Saved dataframe_[4] to the df_3 sub-directory
# Saved dataframe_[5] to the df_3 sub-directory
# Saved dataframe_[0] to the df_3 sub-directory
# Saved dataframe_[1] to the df_4 sub-directory
# Saved dataframe_[3] to the df_4 sub-directory
# Saved dataframe_[4] to the df_4 sub-directory
# Saved dataframe_[0] to the df_4 sub-directory
# Saved dataframe_[2] to the df_4 sub-directory
# Saved dataframe_[5] to the df_4 sub-directory
# Saved dataframe_[1] to the df_5 sub-directory
# Saved dataframe_[2] to the df_5 sub-directory
# Saved dataframe_[3] to the df_5 sub-directory
# Saved dataframe_[4] to the df_5 sub-directory
# Saved dataframe_[5] to the df_5 sub-directory
# Saved dataframe_[0] to the df_5 sub-directory
# Saved dataframe_[1] to the df_6 sub-directory
# Saved dataframe_[2] to the df_6 sub-directory
# Saved dataframe_[4] to the df_6 sub-directory
# Saved dataframe_[0] to the df_6 sub-directory
# Saved dataframe_[3] to the df_6 sub-directory
# Saved dataframe_[5] to the df_6 sub-directory
# Saved dataframe_[0] to the df_7 sub-directory
# Saved dataframe_[1] to the df_7 sub-directory
# Saved dataframe_[2] to the df_7 sub-directory
# Saved dataframe_[3] to the df_7 sub-directory
# Saved dataframe_[4] to the df_7 sub-directory
# Saved dataframe_[5] to the df_7 sub-directory
# Saved dataframe_[0] to the df_8 sub-directory
# Saved dataframe_[1] to the df_8 sub-directory
# Saved dataframe_[3] to the df_8 sub-directory
# Saved dataframe_[5] to the df_8 sub-directory
# Saved dataframe_[2] to the df_8 sub-directory
# Saved dataframe_[4] to the df_8 sub-directory
# Saved dataframe_[0] to the df_9 sub-directory
# Saved dataframe_[3] to the df_9 sub-directory
# Saved dataframe_[1] to the df_9 sub-directory
# Saved dataframe_[2] to the df_9 sub-directory
# Saved dataframe_[4] to the df_9 sub-directory
# Saved dataframe_[5] to the df_9 sub-directory
# Saved dataframe_[0] to the df_10 sub-directory
# Saved dataframe_[2] to the df_10 sub-directory
# Saved dataframe_[5] to the df_10 sub-directory
# Saved dataframe_[1] to the df_10 sub-directory
# Saved dataframe_[3] to the df_10 sub-directory
# Saved dataframe_[4] to the df_10 sub-directory
# Saved dataframe_[0] to the df_11 sub-directory
# Saved dataframe_[3] to the df_11 sub-directory
# Saved dataframe_[5] to the df_11 sub-directory
# Saved dataframe_[1] to the df_11 sub-directory
# Saved dataframe_[4] to the df_11 sub-directory
# Saved dataframe_[2] to the df_11 sub-directory
# Saved dataframe_[3] to the df_12 sub-directory
# Saved dataframe_[5] to the df_12 sub-directory
# Saved dataframe_[0] to the df_12 sub-directory
# Saved dataframe_[1] to the df_12 sub-directory
# Saved dataframe_[2] to the df_12 sub-directory
# Saved dataframe_[4] to the df_12 sub-directory
# Saved dataframe_[1] to the df_13 sub-directory
# Saved dataframe_[2] to the df_13 sub-directory
# Saved dataframe_[4] to the df_13 sub-directory
# Saved dataframe_[0] to the df_13 sub-directory
# Saved dataframe_[3] to the df_13 sub-directory
# Saved dataframe_[5] to the df_13 sub-directory
# Saved dataframe_[0] to the df_14 sub-directory
# Saved dataframe_[2] to the df_14 sub-directory
# Saved dataframe_[5] to the df_14 sub-directory
# Saved dataframe_[1] to the df_14 sub-directory
# Saved dataframe_[3] to the df_14 sub-directory
# Saved dataframe_[4] to the df_14 sub-directory
# Saved dataframe_[0] to the df_15 sub-directory
# Saved dataframe_[4] to the df_15 sub-directory
# Saved dataframe_[1] to the df_15 sub-directory
# Saved dataframe_[2] to the df_15 sub-directory
# Saved dataframe_[3] to the df_15 sub-directory
# Saved dataframe_[5] to the df_15 sub-directory
# Saved dataframe_[4] to the df_16 sub-directory
# Saved dataframe_[5] to the df_16 sub-directory
# Saved dataframe_[2] to the df_16 sub-directory
# Saved dataframe_[3] to the df_16 sub-directory
# Saved dataframe_[0] to the df_16 sub-directory
# Saved dataframe_[1] to the df_16 sub-directory
# Saved dataframe_[1] to the df_17 sub-directory
# Saved dataframe_[4] to the df_17 sub-directory
# Saved dataframe_[0] to the df_17 sub-directory
# Saved dataframe_[2] to the df_17 sub-directory
# Saved dataframe_[3] to the df_17 sub-directory
# Saved dataframe_[5] to the df_17 sub-directory
# Saved dataframe_[1] to the df_18 sub-directory
# Saved dataframe_[0] to the df_18 sub-directory
# Saved dataframe_[2] to the df_18 sub-directory
# Saved dataframe_[3] to the df_18 sub-directory
# Saved dataframe_[4] to the df_18 sub-directory
# Saved dataframe_[5] to the df_18 sub-directory
# Saved dataframe_[1] to the df_19 sub-directory
# Saved dataframe_[2] to the df_19 sub-directory
# Saved dataframe_[0] to the df_19 sub-directory
# Saved dataframe_[3] to the df_19 sub-directory
# Saved dataframe_[4] to the df_19 sub-directory
# Saved dataframe_[5] to the df_19 sub-directory
# Saved dataframe_[0] to the df_20 sub-directory
# Saved dataframe_[1] to the df_20 sub-directory
# Saved dataframe_[2] to the df_20 sub-directory
# Saved dataframe_[3] to the df_20 sub-directory
# Saved dataframe_[4] to the df_20 sub-directory
# Saved dataframe_[5] to the df_20 sub-directory
# Saved dataframe_[0] to the df_21 sub-directory
# Saved dataframe_[2] to the df_21 sub-directory
# Saved dataframe_[1] to the df_21 sub-directory
# Saved dataframe_[3] to the df_21 sub-directory
# Saved dataframe_[4] to the df_21 sub-directory
# Saved dataframe_[5] to the df_21 sub-directory
# Saved dataframe_[1] to the df_22 sub-directory
# Saved dataframe_[2] to the df_22 sub-directory
# Saved dataframe_[0] to the df_22 sub-directory
# Saved dataframe_[3] to the df_22 sub-directory
# Saved dataframe_[4] to the df_22 sub-directory
# Saved dataframe_[5] to the df_22 sub-directory
# Saved dataframe_[2] to the df_23 sub-directory
# Saved dataframe_[0] to the df_23 sub-directory
# Saved dataframe_[1] to the df_23 sub-directory
# Saved dataframe_[3] to the df_23 sub-directory
# Saved dataframe_[4] to the df_23 sub-directory
# Saved dataframe_[5] to the df_23 sub-directory
# Saved dataframe_[2] to the df_24 sub-directory
# Saved dataframe_[4] to the df_24 sub-directory
# Saved dataframe_[5] to the df_24 sub-directory
# Saved dataframe_[0] to the df_24 sub-directory
# Saved dataframe_[1] to the df_24 sub-directory
# Saved dataframe_[3] to the df_24 sub-directory
# Saved dataframe_[2] to the df_25 sub-directory
# Saved dataframe_[3] to the df_25 sub-directory
# Saved dataframe_[4] to the df_25 sub-directory
# Saved dataframe_[0] to the df_25 sub-directory
# Saved dataframe_[1] to the df_25 sub-directory
# Saved dataframe_[5] to the df_25 sub-directory
# Saved dataframe_[2] to the df_26 sub-directory
# Saved dataframe_[3] to the df_26 sub-directory
# Saved dataframe_[0] to the df_26 sub-directory
# Saved dataframe_[1] to the df_26 sub-directory
# Saved dataframe_[4] to the df_26 sub-directory
# Saved dataframe_[5] to the df_26 sub-directory
# Saved dataframe_[4] to the df_27 sub-directory
# Saved dataframe_[0] to the df_27 sub-directory
# Saved dataframe_[1] to the df_27 sub-directory
# Saved dataframe_[2] to the df_27 sub-directory
# Saved dataframe_[3] to the df_27 sub-directory
# Saved dataframe_[5] to the df_27 sub-directory
# Saved dataframe_[1] to the df_28 sub-directory
# Saved dataframe_[2] to the df_28 sub-directory
# Saved dataframe_[3] to the df_28 sub-directory
# Saved dataframe_[0] to the df_28 sub-directory
# Saved dataframe_[4] to the df_28 sub-directory
# Saved dataframe_[5] to the df_28 sub-directory
# Saved dataframe_[1] to the df_29 sub-directory
# Saved dataframe_[2] to the df_29 sub-directory
# Saved dataframe_[0] to the df_29 sub-directory
# Saved dataframe_[3] to the df_29 sub-directory
# Saved dataframe_[4] to the df_29 sub-directory
# Saved dataframe_[5] to the df_29 sub-directory
# Saved dataframe_[0] to the df_30 sub-directory
# Saved dataframe_[2] to the df_30 sub-directory
# Saved dataframe_[5] to the df_30 sub-directory
# Saved dataframe_[1] to the df_30 sub-directory
# Saved dataframe_[3] to the df_30 sub-directory
# Saved dataframe_[4] to the df_30 sub-directory
# Saved dataframe_[1] to the df_31 sub-directory
# Saved dataframe_[0] to the df_31 sub-directory
# Saved dataframe_[3] to the df_31 sub-directory
# Saved dataframe_[4] to the df_31 sub-directory
# Saved dataframe_[5] to the df_31 sub-directory
# Saved dataframe_[2] to the df_31 sub-directory
# Saved dataframe_[2] to the df_32 sub-directory
# Saved dataframe_[5] to the df_32 sub-directory
# Saved dataframe_[0] to the df_32 sub-directory
# Saved dataframe_[1] to the df_32 sub-directory
# Saved dataframe_[3] to the df_32 sub-directory
# Saved dataframe_[4] to the df_32 sub-directory
# Saved dataframe_[5] to the df_33 sub-directory
# Saved dataframe_[0] to the df_33 sub-directory
# Saved dataframe_[3] to the df_33 sub-directory
# Saved dataframe_[4] to the df_33 sub-directory
# Saved dataframe_[1] to the df_33 sub-directory
# Saved dataframe_[2] to the df_33 sub-directory
# Saved dataframe_[1] to the df_34 sub-directory
# Saved dataframe_[3] to the df_34 sub-directory
# Saved dataframe_[4] to the df_34 sub-directory
# Saved dataframe_[0] to the df_34 sub-directory
# Saved dataframe_[2] to the df_34 sub-directory
# Saved dataframe_[5] to the df_34 sub-directory
# Saved dataframe_[0] to the df_35 sub-directory
# Saved dataframe_[1] to the df_35 sub-directory
# Saved dataframe_[2] to the df_35 sub-directory
# Saved dataframe_[3] to the df_35 sub-directory
# Saved dataframe_[4] to the df_35 sub-directory
# Saved dataframe_[5] to the df_35 sub-directory
# Saved dataframe_[1] to the df_36 sub-directory
# Saved dataframe_[5] to the df_36 sub-directory
# Saved dataframe_[0] to the df_36 sub-directory
# Saved dataframe_[3] to the df_36 sub-directory
# Saved dataframe_[2] to the df_36 sub-directory
# Saved dataframe_[4] to the df_36 sub-directory
# Saved dataframe_[0] to the df_37 sub-directory
# Saved dataframe_[1] to the df_37 sub-directory
# Saved dataframe_[2] to the df_37 sub-directory
# Saved dataframe_[3] to the df_37 sub-directory
# Saved dataframe_[4] to the df_37 sub-directory
# Saved dataframe_[5] to the df_37 sub-directory
# Saved dataframe_[0] to the df_38 sub-directory
# Saved dataframe_[1] to the df_38 sub-directory
# Saved dataframe_[2] to the df_38 sub-directory
# Saved dataframe_[3] to the df_38 sub-directory
# Saved dataframe_[4] to the df_38 sub-directory
# Saved dataframe_[5] to the df_38 sub-directory
# Saved dataframe_[0] to the df_39 sub-directory
# Saved dataframe_[1] to the df_39 sub-directory
# Saved dataframe_[2] to the df_39 sub-directory
# Saved dataframe_[3] to the df_39 sub-directory
# Saved dataframe_[4] to the df_39 sub-directory
# Saved dataframe_[5] to the df_39 sub-directory
# Saved dataframe_[0] to the df_40 sub-directory
# Saved dataframe_[1] to the df_40 sub-directory
# Saved dataframe_[2] to the df_40 sub-directory
# Saved dataframe_[3] to the df_40 sub-directory
# Saved dataframe_[4] to the df_40 sub-directory
# Saved dataframe_[5] to the df_40 sub-directory
# Saved dataframe_[1] to the df_41 sub-directory
# Saved dataframe_[2] to the df_41 sub-directory
# Saved dataframe_[3] to the df_41 sub-directory
# Saved dataframe_[0] to the df_41 sub-directory
# Saved dataframe_[4] to the df_41 sub-directory
# Saved dataframe_[5] to the df_41 sub-directory
# Saved dataframe_[1] to the df_42 sub-directory
# Saved dataframe_[4] to the df_42 sub-directory
# Saved dataframe_[0] to the df_42 sub-directory
# Saved dataframe_[2] to the df_42 sub-directory
# Saved dataframe_[3] to the df_42 sub-directory
# Saved dataframe_[5] to the df_42 sub-directory
# Saved dataframe_[0] to the df_43 sub-directory
# Saved dataframe_[1] to the df_43 sub-directory
# Saved dataframe_[2] to the df_43 sub-directory
# Saved dataframe_[3] to the df_43 sub-directory
# Saved dataframe_[5] to the df_43 sub-directory
# Saved dataframe_[4] to the df_43 sub-directory
# Saved dataframe_[1] to the df_44 sub-directory
# Saved dataframe_[0] to the df_44 sub-directory
# Saved dataframe_[2] to the df_44 sub-directory
# Saved dataframe_[3] to the df_44 sub-directory
# Saved dataframe_[4] to the df_44 sub-directory
# Saved dataframe_[5] to the df_44 sub-directory
# Saved dataframe_[2] to the df_45 sub-directory
# Saved dataframe_[4] to the df_45 sub-directory
# Saved dataframe_[0] to the df_45 sub-directory
# Saved dataframe_[1] to the df_45 sub-directory
# Saved dataframe_[3] to the df_45 sub-directory
# Saved dataframe_[5] to the df_45 sub-directory
# Saved dataframe_[2] to the df_46 sub-directory
# Saved dataframe_[3] to the df_46 sub-directory
# Saved dataframe_[5] to the df_46 sub-directory
# Saved dataframe_[0] to the df_46 sub-directory
# Saved dataframe_[1] to the df_46 sub-directory
# Saved dataframe_[4] to the df_46 sub-directory
# Saved dataframe_[0] to the df_47 sub-directory
# Saved dataframe_[1] to the df_47 sub-directory
# Saved dataframe_[3] to the df_47 sub-directory
# Saved dataframe_[2] to the df_47 sub-directory
# Saved dataframe_[4] to the df_47 sub-directory
# Saved dataframe_[5] to the df_47 sub-directory
# Saved dataframe_[0] to the df_48 sub-directory
# Saved dataframe_[3] to the df_48 sub-directory
# Saved dataframe_[1] to the df_48 sub-directory
# Saved dataframe_[2] to the df_48 sub-directory
# Saved dataframe_[4] to the df_48 sub-directory
# Saved dataframe_[5] to the df_48 sub-directory
# Saved dataframe_[2] to the df_49 sub-directory
# Saved dataframe_[4] to the df_49 sub-directory
# Saved dataframe_[0] to the df_49 sub-directory
# Saved dataframe_[1] to the df_49 sub-directory
# Saved dataframe_[3] to the df_49 sub-directory
# Saved dataframe_[5] to the df_49 sub-directory
# Saved dataframe_[0] to the df_50 sub-directory
# Saved dataframe_[2] to the df_50 sub-directory
# Saved dataframe_[3] to the df_50 sub-directory
# Saved dataframe_[1] to the df_50 sub-directory
# Saved dataframe_[4] to the df_50 sub-directory
# Saved dataframe_[5] to the df_50 sub-directory
# Saved dataframe_[0] to the df_51 sub-directory
# Saved dataframe_[3] to the df_51 sub-directory
# Saved dataframe_[1] to the df_51 sub-directory
# Saved dataframe_[2] to the df_51 sub-directory
# Saved dataframe_[5] to the df_51 sub-directory
# Saved dataframe_[4] to the df_51 sub-directory
# Saved dataframe_[1] to the df_52 sub-directory
# Saved dataframe_[0] to the df_52 sub-directory
# Saved dataframe_[2] to the df_52 sub-directory
# Saved dataframe_[3] to the df_52 sub-directory
# Saved dataframe_[4] to the df_52 sub-directory
# Saved dataframe_[5] to the df_52 sub-directory
# Saved dataframe_[2] to the df_53 sub-directory
# Saved dataframe_[4] to the df_53 sub-directory
# Saved dataframe_[1] to the df_53 sub-directory
# Saved dataframe_[3] to the df_53 sub-directory
# Saved dataframe_[5] to the df_53 sub-directory
# Saved dataframe_[0] to the df_53 sub-directory
# Saved dataframe_[2] to the df_54 sub-directory
# Saved dataframe_[0] to the df_54 sub-directory
# Saved dataframe_[1] to the df_54 sub-directory
# Saved dataframe_[4] to the df_54 sub-directory
# Saved dataframe_[5] to the df_54 sub-directory
# Saved dataframe_[3] to the df_54 sub-directory
# Saved dataframe_[2] to the df_55 sub-directory
# Saved dataframe_[1] to the df_55 sub-directory
# Saved dataframe_[3] to the df_55 sub-directory
# Saved dataframe_[4] to the df_55 sub-directory
# Saved dataframe_[0] to the df_55 sub-directory
# Saved dataframe_[5] to the df_55 sub-directory
# Saved dataframe_[0] to the df_56 sub-directory
# Saved dataframe_[3] to the df_56 sub-directory
# Saved dataframe_[4] to the df_56 sub-directory
# Saved dataframe_[1] to the df_56 sub-directory
# Saved dataframe_[2] to the df_56 sub-directory
# Saved dataframe_[5] to the df_56 sub-directory
# Saved dataframe_[1] to the df_57 sub-directory
# Saved dataframe_[2] to the df_57 sub-directory
# Saved dataframe_[5] to the df_57 sub-directory
# Saved dataframe_[0] to the df_57 sub-directory
# Saved dataframe_[4] to the df_57 sub-directory
# Saved dataframe_[3] to the df_57 sub-directory
# Saved dataframe_[0] to the df_58 sub-directory
# Saved dataframe_[1] to the df_58 sub-directory
# Saved dataframe_[2] to the df_58 sub-directory
# Saved dataframe_[3] to the df_58 sub-directory
# Saved dataframe_[4] to the df_58 sub-directory
# Saved dataframe_[5] to the df_58 sub-directory
# Saved dataframe_[3] to the df_59 sub-directory
# Saved dataframe_[4] to the df_59 sub-directory
# Saved dataframe_[0] to the df_59 sub-directory
# Saved dataframe_[1] to the df_59 sub-directory
# Saved dataframe_[2] to the df_59 sub-directory
# Saved dataframe_[5] to the df_59 sub-directory
# Saved dataframe_[5] to the df_60 sub-directory
# Saved dataframe_[4] to the df_60 sub-directory
# Saved dataframe_[0] to the df_60 sub-directory
# Saved dataframe_[1] to the df_60 sub-directory
# Saved dataframe_[3] to the df_60 sub-directory
# Saved dataframe_[2] to the df_60 sub-directory
# Saved dataframe_[4] to the df_61 sub-directory
# Saved dataframe_[5] to the df_61 sub-directory
# Saved dataframe_[0] to the df_61 sub-directory
# Saved dataframe_[1] to the df_61 sub-directory
# Saved dataframe_[2] to the df_61 sub-directory
# Saved dataframe_[3] to the df_61 sub-directory
# Saved dataframe_[0] to the df_62 sub-directory
# Saved dataframe_[2] to the df_62 sub-directory
# Saved dataframe_[3] to the df_62 sub-directory
# Saved dataframe_[4] to the df_62 sub-directory
# Saved dataframe_[1] to the df_62 sub-directory
# Saved dataframe_[5] to the df_62 sub-directory
# Saved dataframe_[1] to the df_63 sub-directory
# Saved dataframe_[3] to the df_63 sub-directory
# Saved dataframe_[0] to the df_63 sub-directory
# Saved dataframe_[2] to the df_63 sub-directory
# Saved dataframe_[4] to the df_63 sub-directory
# Saved dataframe_[5] to the df_63 sub-directory
# Saved dataframe_[0] to the df_64 sub-directory
# Saved dataframe_[4] to the df_64 sub-directory
# Saved dataframe_[5] to the df_64 sub-directory
# Saved dataframe_[1] to the df_64 sub-directory
# Saved dataframe_[2] to the df_64 sub-directory
# Saved dataframe_[3] to the df_64 sub-directory
# Saved dataframe_[1] to the df_65 sub-directory
# Saved dataframe_[2] to the df_65 sub-directory
# Saved dataframe_[3] to the df_65 sub-directory
# Saved dataframe_[5] to the df_65 sub-directory
# Saved dataframe_[0] to the df_65 sub-directory
# Saved dataframe_[4] to the df_65 sub-directory
# Saved dataframe_[2] to the df_66 sub-directory
# Saved dataframe_[4] to the df_66 sub-directory
# Saved dataframe_[0] to the df_66 sub-directory
# Saved dataframe_[1] to the df_66 sub-directory
# Saved dataframe_[3] to the df_66 sub-directory
# Saved dataframe_[5] to the df_66 sub-directory
# Saved dataframe_[0] to the df_67 sub-directory
# Saved dataframe_[3] to the df_67 sub-directory
# Saved dataframe_[2] to the df_67 sub-directory
# Saved dataframe_[4] to the df_67 sub-directory
# Saved dataframe_[5] to the df_67 sub-directory
# Saved dataframe_[1] to the df_67 sub-directory
# Saved dataframe_[0] to the df_68 sub-directory
# Saved dataframe_[2] to the df_68 sub-directory
# Saved dataframe_[1] to the df_68 sub-directory
# Saved dataframe_[3] to the df_68 sub-directory
# Saved dataframe_[5] to the df_68 sub-directory
# Saved dataframe_[4] to the df_68 sub-directory
# Saved dataframe_[4] to the df_69 sub-directory
# Saved dataframe_[5] to the df_69 sub-directory
# Saved dataframe_[0] to the df_69 sub-directory
# Saved dataframe_[1] to the df_69 sub-directory
# Saved dataframe_[2] to the df_69 sub-directory
# Saved dataframe_[3] to the df_69 sub-directory
# Saved dataframe_[4] to the df_70 sub-directory
# Saved dataframe_[0] to the df_70 sub-directory
# Saved dataframe_[1] to the df_70 sub-directory
# Saved dataframe_[2] to the df_70 sub-directory
# Saved dataframe_[3] to the df_70 sub-directory
# Saved dataframe_[5] to the df_70 sub-directory
# Saved dataframe_[0] to the df_71 sub-directory
# Saved dataframe_[1] to the df_71 sub-directory
# Saved dataframe_[4] to the df_71 sub-directory
# Saved dataframe_[5] to the df_71 sub-directory
# Saved dataframe_[2] to the df_71 sub-directory
# Saved dataframe_[3] to the df_71 sub-directory
# Saved dataframe_[5] to the df_72 sub-directory
# Saved dataframe_[0] to the df_72 sub-directory
# Saved dataframe_[2] to the df_72 sub-directory
# Saved dataframe_[3] to the df_72 sub-directory
# Saved dataframe_[4] to the df_72 sub-directory
# Saved dataframe_[1] to the df_72 sub-directory
# Saved dataframe_[4] to the df_73 sub-directory
# Saved dataframe_[0] to the df_73 sub-directory
# Saved dataframe_[1] to the df_73 sub-directory
# Saved dataframe_[2] to the df_73 sub-directory
# Saved dataframe_[3] to the df_73 sub-directory
# Saved dataframe_[5] to the df_73 sub-directory
# Saved dataframe_[1] to the df_74 sub-directory
# Saved dataframe_[5] to the df_74 sub-directory
# Saved dataframe_[0] to the df_74 sub-directory
# Saved dataframe_[2] to the df_74 sub-directory
# Saved dataframe_[3] to the df_74 sub-directory
# Saved dataframe_[4] to the df_74 sub-directory
# Saved dataframe_[0] to the df_75 sub-directory
# Saved dataframe_[1] to the df_75 sub-directory
# Saved dataframe_[2] to the df_75 sub-directory
# Saved dataframe_[3] to the df_75 sub-directory
# Saved dataframe_[4] to the df_75 sub-directory
# Saved dataframe_[5] to the df_75 sub-directory
# Saved dataframe_[1] to the df_76 sub-directory
# Saved dataframe_[2] to the df_76 sub-directory
# Saved dataframe_[3] to the df_76 sub-directory
# Saved dataframe_[4] to the df_76 sub-directory
# Saved dataframe_[0] to the df_76 sub-directory
# Saved dataframe_[5] to the df_76 sub-directory
# Saved dataframe_[0] to the df_77 sub-directory
# Saved dataframe_[1] to the df_77 sub-directory
# Saved dataframe_[2] to the df_77 sub-directory
# Saved dataframe_[3] to the df_77 sub-directory
# Saved dataframe_[4] to the df_77 sub-directory
# Saved dataframe_[5] to the df_77 sub-directory
# Saved dataframe_[2] to the df_78 sub-directory
# Saved dataframe_[0] to the df_78 sub-directory
# Saved dataframe_[1] to the df_78 sub-directory
# Saved dataframe_[3] to the df_78 sub-directory
# Saved dataframe_[4] to the df_78 sub-directory
# Saved dataframe_[5] to the df_78 sub-directory
# Saved dataframe_[0] to the df_79 sub-directory
# Saved dataframe_[3] to the df_79 sub-directory
# Saved dataframe_[1] to the df_79 sub-directory
# Saved dataframe_[2] to the df_79 sub-directory
# Saved dataframe_[4] to the df_79 sub-directory
# Saved dataframe_[5] to the df_79 sub-directory
# Saved dataframe_[3] to the df_80 sub-directory
# Saved dataframe_[0] to the df_80 sub-directory
# Saved dataframe_[1] to the df_80 sub-directory
# Saved dataframe_[4] to the df_80 sub-directory
# Saved dataframe_[5] to the df_80 sub-directory
# Saved dataframe_[2] to the df_80 sub-directory
# Saved dataframe_[0] to the df_81 sub-directory
# Saved dataframe_[1] to the df_81 sub-directory
# Saved dataframe_[2] to the df_81 sub-directory
# Saved dataframe_[3] to the df_81 sub-directory
# Saved dataframe_[4] to the df_81 sub-directory
# Saved dataframe_[5] to the df_81 sub-directory
# Saved dataframe_[1] to the df_82 sub-directory
# Saved dataframe_[4] to the df_82 sub-directory
# Saved dataframe_[0] to the df_82 sub-directory
# Saved dataframe_[3] to the df_82 sub-directory
# Saved dataframe_[5] to the df_82 sub-directory
# Saved dataframe_[2] to the df_82 sub-directory
# Saved dataframe_[4] to the df_83 sub-directory
# Saved dataframe_[1] to the df_83 sub-directory
# Saved dataframe_[2] to the df_83 sub-directory
# Saved dataframe_[3] to the df_83 sub-directory
# Saved dataframe_[5] to the df_83 sub-directory
# Saved dataframe_[0] to the df_83 sub-directory
# Saved dataframe_[5] to the df_84 sub-directory
# Saved dataframe_[0] to the df_84 sub-directory
# Saved dataframe_[3] to the df_84 sub-directory
# Saved dataframe_[1] to the df_84 sub-directory
# Saved dataframe_[2] to the df_84 sub-directory
# Saved dataframe_[4] to the df_84 sub-directory
# Saved dataframe_[0] to the df_85 sub-directory
# Saved dataframe_[1] to the df_85 sub-directory
# Saved dataframe_[3] to the df_85 sub-directory
# Saved dataframe_[4] to the df_85 sub-directory
# Saved dataframe_[5] to the df_85 sub-directory
# Saved dataframe_[2] to the df_85 sub-directory
# Saved dataframe_[1] to the df_86 sub-directory
# Saved dataframe_[2] to the df_86 sub-directory
# Saved dataframe_[3] to the df_86 sub-directory
# Saved dataframe_[5] to the df_86 sub-directory
# Saved dataframe_[0] to the df_86 sub-directory
# Saved dataframe_[4] to the df_86 sub-directory
# Saved dataframe_[2] to the df_87 sub-directory
# Saved dataframe_[3] to the df_87 sub-directory
# Saved dataframe_[1] to the df_87 sub-directory
# Saved dataframe_[4] to the df_87 sub-directory
# Saved dataframe_[5] to the df_87 sub-directory
# Saved dataframe_[0] to the df_87 sub-directory
# Saved dataframe_[4] to the df_88 sub-directory
# Saved dataframe_[0] to the df_88 sub-directory
# Saved dataframe_[3] to the df_88 sub-directory
# Saved dataframe_[5] to the df_88 sub-directory
# Saved dataframe_[1] to the df_88 sub-directory
# Saved dataframe_[2] to the df_88 sub-directory
# Saved dataframe_[1] to the df_89 sub-directory
# Saved dataframe_[0] to the df_89 sub-directory
# Saved dataframe_[2] to the df_89 sub-directory
# Saved dataframe_[3] to the df_89 sub-directory
# Saved dataframe_[4] to the df_89 sub-directory
# Saved dataframe_[5] to the df_89 sub-directory
# Saved dataframe_[3] to the df_90 sub-directory
# Saved dataframe_[1] to the df_90 sub-directory
# Saved dataframe_[2] to the df_90 sub-directory
# Saved dataframe_[4] to the df_90 sub-directory
# Saved dataframe_[5] to the df_90 sub-directory
# Saved dataframe_[0] to the df_90 sub-directory
# Saved dataframe_[0] to the df_91 sub-directory
# Saved dataframe_[3] to the df_91 sub-directory
# Saved dataframe_[1] to the df_91 sub-directory
# Saved dataframe_[2] to the df_91 sub-directory
# Saved dataframe_[4] to the df_91 sub-directory
# Saved dataframe_[5] to the df_91 sub-directory
# Saved dataframe_[0] to the df_92 sub-directory
# Saved dataframe_[3] to the df_92 sub-directory
# Saved dataframe_[1] to the df_92 sub-directory
# Saved dataframe_[2] to the df_92 sub-directory
# Saved dataframe_[5] to the df_92 sub-directory
# Saved dataframe_[4] to the df_92 sub-directory
# Saved dataframe_[0] to the df_93 sub-directory
# Saved dataframe_[2] to the df_93 sub-directory
# Saved dataframe_[1] to the df_93 sub-directory
# Saved dataframe_[4] to the df_93 sub-directory
# Saved dataframe_[3] to the df_93 sub-directory
# Saved dataframe_[5] to the df_93 sub-directory
# Saved dataframe_[2] to the df_94 sub-directory
# Saved dataframe_[4] to the df_94 sub-directory
# Saved dataframe_[5] to the df_94 sub-directory
# Saved dataframe_[0] to the df_94 sub-directory
# Saved dataframe_[1] to the df_94 sub-directory
# Saved dataframe_[3] to the df_94 sub-directory
# Saved dataframe_[0] to the df_95 sub-directory
# Saved dataframe_[1] to the df_95 sub-directory
# Saved dataframe_[2] to the df_95 sub-directory
# Saved dataframe_[3] to the df_95 sub-directory
# Saved dataframe_[4] to the df_95 sub-directory
# Saved dataframe_[5] to the df_95 sub-directory
# Saved dataframe_[0] to the df_96 sub-directory
# Saved dataframe_[1] to the df_96 sub-directory
# Saved dataframe_[2] to the df_96 sub-directory
# Saved dataframe_[3] to the df_96 sub-directory
# Saved dataframe_[5] to the df_96 sub-directory
# Saved dataframe_[4] to the df_96 sub-directory
# Saved dataframe_[0] to the df_97 sub-directory
# Saved dataframe_[1] to the df_97 sub-directory
# Saved dataframe_[4] to the df_97 sub-directory
# Saved dataframe_[2] to the df_97 sub-directory
# Saved dataframe_[3] to the df_97 sub-directory
# Saved dataframe_[5] to the df_97 sub-directory
# Saved dataframe_[2] to the df_98 sub-directory
# Saved dataframe_[5] to the df_98 sub-directory
# Saved dataframe_[0] to the df_98 sub-directory
# Saved dataframe_[1] to the df_98 sub-directory
# Saved dataframe_[3] to the df_98 sub-directory
# Saved dataframe_[4] to the df_98 sub-directory
# Saved dataframe_[1] to the df_99 sub-directory
# Saved dataframe_[3] to the df_99 sub-directory
# Saved dataframe_[5] to the df_99 sub-directory
# Saved dataframe_[0] to the df_99 sub-directory
# Saved dataframe_[4] to the df_99 sub-directory
# Saved dataframe_[2] to the df_99 sub-directory
# File saved to sim-samp100-T100-sim100-redo-shuffled.npz 	Time taken: 37.813s

# %%
command = f"%run {sim_script} -o {sim_out} --simulations 100 --pop_limit 10000 --sample 100 --mu 0 -T 100 -i {init_file}"

# %% [markdown]
# <a id="10"></a>
# ## back projection application

# %% [markdown]
# <a id="11"></a>
# ### parallel with 10 shuffled parent directories

# %%
back_dir_w_str       = 'back-projected-func-write-sim10000'

dirs_list = []
for i in range(10):
    for j in range(10000):
        dir_str = back_dir_w_str + f'/df_{j}'
        dirs_list.append(dir_str)

for name in dirs_list:
    dir_path = ppath.join(SSH_DATA, name)
    if name!=dirs_list[-1]:
        print(f'mkdir {dir_path} &&')
    else:
        print(f'mkdir {dir_path}')

# %%
# parallel

script_file      = 'back_projection_ems.py'
script_path      = os.path.join(SSH_DATA, script_file)
bp_read_str       = 'back-projected-sim1000'
bp_write_str    =  'back-projected-sim1000-write'

dirs_write = []
dirs_read = []
for i in range(10):
    #for j in range(1000):
    write_str = bp_write_str + f'-{i}'
    read_str = bp_read_str + f'-{i}'
    
    dirs_write.append(write_str)
    dirs_read.append(read_str)
    
for i in range(10):
    #dir_path = ppath.join(SSH_DATA, name)
    #if name!=dirs_list[-1]:
        #print(dir_path)
    job_file         = f'job-bp-sim-{i}.sh'
    job_str          = f"""#!/bin/bash -l
    #!/bin/bash
    #SBATCH --job-name=back-projection-sim-{i}
    #SBATCH --output=bp-sim-{i}_%a.out
    #SBATCH --error=bp-sim-{i}_%a.err
    #SBATCH --nodes=1
    #SBATCH --ntasks=1
    #SBATCH --cpus-per-task=1
    #SBATCH --mem=1G
    #SBATCH --mail-user={USER_EMAIL}
    #SBATCH --mail-type=ALL
    #SBATCH --time 03:00:00
    #SBATCH --array=0-999

    # scripts takes the file path of the directory as input parameter

    DIRS=({SSH_DATA}/{bp_read_str}-{i}/df_*/) # Create a Bash array with all data directories
    WRITE_DIRS=({SSH_DATA}/{bp_write_str}-{i}/df_*/)

    module unload miniconda2
    module load miniconda3
    conda activate sars-env

    # Feed the script with the data directory corresponding to the task ID in the array

    python {script_file} -read_dir "${{DIRS[$SLURM_ARRAY_TASK_ID]}}" -incubation_file 'incubation_period_sars2.csv' -smoothing_file 'weights_binom.csv' -write_dir "${{WRITE_DIRS[$SLURM_ARRAY_TASK_ID]}}"
    """ 

    f = open(os.path.join(SIM_DIR, job_file), mode='w')
    f.write('%s\n' % job_str)
    f.close()
    
    job_path = os.path.join(SIM_DIR, job_file)

    #print(f'scp {job_path} {SSH_HOME}{SSH_DATA}')

    #print('')

    # commands to execute on the cluster
    print('sbatch %s' % job_file)
    print('')

# %% [markdown]
# <a id="12"></a>
# ### large object, from 10000 shuffled simulations

# %%
# not recommended
# note: previous cluster had cutoff of 2500 array jobs

script_file      = 'back_projection_ems.py'
script_path      = os.path.join(SSH_DATA, script_file)
bp_read_str       = 'back-projected-func-sim10000'
bp_write_str      = 'back-projected-func-write-sim10000'


job_file         = 'job-bp-sim-10000-d.sh'
job_str          = f"""#!/bin/bash -l
#!/bin/bash
#SBATCH --job-name=back-projection-sim
#SBATCH --output=bp-sim_%a.out
#SBATCH --error=bp-sim_%a.err
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=1
#SBATCH --mem=1G
#SBATCH --mail-user={USER_EMAIL}
#SBATCH --mail-type=ALL
#SBATCH --time 03:00:00
#SBATCH --array=7500-9999

# scripts takes the file path of the directory as input parameter

DIRS=({SSH_DATA}/{bp_read_str}/df_*/) # Create a Bash array with all data directories
WRITE_DIRS=({SSH_DATA}/{bp_write_str}/df_*/)

module unload miniconda2
module load miniconda3
conda activate sars-env

# Feed the script with the data directory corresponding to the task ID in the array

python {script_file} -read_dir "${{DIRS[$SLURM_ARRAY_TASK_ID]}}" -incubation_file 'incubation_period_sars2.csv' -smoothing_file 'weights_binom.csv' -write_dir "${{WRITE_DIRS[$SLURM_ARRAY_TASK_ID]}}"
""" 

f = open(os.path.join(SIM_DIR, job_file), mode='w')
f.write('%s\n' % job_str)
f.close()


job_path = os.path.join(SIM_DIR, job_file)

print(f'scp {job_path} {SSH_HOME}{SSH_DATA}')

print('')

# commands to execute on the cluster
print('sbatch %s' % job_file)
print('')

# %% [markdown]
# <a id="13"></a>
# ### local running

# %%
BP_LOC_DIR        = os.path.join(SIM_DIR, 'back-projected-redo')
BP_LOC_DIR_WRITE  = os.path.join(SIM_DIR, 'back-projected-redo-write')

READ_1 = os.path.join(BP_LOC_DIR, 'df_1')
WRITE_1 = os.path.join(BP_LOC_DIR_WRITE, 'df_1')

# %%
command = f"%run {bp_script} -read_dir {READ_0} -write_dir {WRITE_0} -incubation_file {incubation_file} -smoothing_file {smoothing_file}"

# %%
command
# Out:
# '%run back_projection_ems.py -read_dir /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo/df_0 -write_dir /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo-write/df_0 -incubation_file incubation_period_sars2.csv -smoothing_file weights_binom.csv'

# %% [markdown]
# #### example

# %%
# %%time

# %run back_projection_ems.py -read_dir {BP_LOC_DIR}/df_6 -write_dir {BP_LOC_WRITE_DIR}/df_6 -incubation_file incubation_period_sars2.csv -smoothing_file weights_binom.csv
print("done")
# %run back_projection_ems.py -read_dir {BP_LOC_DIR}/df_7 -write_dir {BP_LOC_WRITE_DIR}/df_7 -incubation_file incubation_period_sars2.csv -smoothing_file weights_binom.csv
print("done")
# %run back_projection_ems.py -read_dir {BP_LOC_DIR}/df_8 -write_dir {BP_LOC_WRITE_DIR}/df_8 -incubation_file incubation_period_sars2.csv -smoothing_file weights_binom.csv
print("done")
# %run back_projection_ems.py -read_dir {BP_LOC_DIR}/df_9 -write_dir {BP_LOC_WRITE_DIR}/df_9 -incubation_file incubation_period_sars2.csv -smoothing_file weights_binom.csv
print("done")
# %run back_projection_ems.py -read_dir {BP_LOC_DIR}/df_10 -write_dir {BP_LOC_WRITE_DIR}/df_10 -incubation_file incubation_period_sars2.csv -smoothing_file weights_binom.csv
print("done")
# %run back_projection_ems.py -read_dir {BP_LOC_DIR}/df_11 -write_dir {BP_LOC_WRITE_DIR}/df_11 -incubation_file incubation_period_sars2.csv -smoothing_file weights_binom.csv
print("done")
# Out:
# /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo/df_6
# iter	epsilon
# 1	4.43e+03
# 2	2.14e-02
# 3	7.83e-03
# 4	3.63e-03
# 5	1.84e-03
# 6	9.92e-04
# 7	5.46e-04
# 8	3.06e-04
# 9	1.74e-04
# 10	1.00e-04
# 11	5.75e-05
# iter	epsilon
# 1	2.42e+03
# 2	3.66e-02
# 3	1.30e-02
# 4	6.80e-03
# 5	3.76e-03
# 6	2.09e-03
# 7	1.18e-03
# 8	6.63e-04
# 9	3.76e-04
# 10	2.15e-04
# 11	1.24e-04
# 12	7.24e-05
# iter	epsilon
# 1	6.18e+02
# 2	5.07e-02
# 3	2.07e-02
# 4	1.09e-02
# 5	6.17e-03
# 6	3.54e-03
# 7	2.06e-03
# 8	1.21e-03
# 9	7.14e-04
# 10	4.24e-04
# 11	2.54e-04
# 12	1.52e-04
# 13	9.14e-05
# iter	epsilon
# 1	3.97e+02
# 2	6.32e-02
# 3	2.66e-02
# 4	1.33e-02
# 5	7.14e-03
# 6	3.90e-03
# 7	2.16e-03
# 8	1.21e-03
# 9	6.80e-04
# 10	3.86e-04
# 11	2.21e-04
# 12	1.27e-04
# 13	7.37e-05
# iter	epsilon
# 1	5.27e+02
# 2	7.30e-02
# 3	2.46e-02
# 4	9.71e-03
# 5	4.55e-03
# 6	2.52e-03
# 7	1.46e-03
# 8	8.74e-04
# 9	5.25e-04
# 10	3.16e-04
# 11	1.91e-04
# 12	1.15e-04
# 13	7.00e-05
# iter	epsilon
# 1	1.70e+03
# 2	2.73e-02
# 3	1.05e-02
# 4	5.21e-03
# 5	2.74e-03
# 6	1.48e-03
# 7	8.13e-04
# 8	4.58e-04
# 9	2.68e-04
# 10	1.59e-04
# 11	9.49e-05
# done
# /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo/df_7
# iter	epsilon
# 1	3.62e+03
# 2	2.71e-02
# 3	9.99e-03
# 4	4.82e-03
# 5	2.55e-03
# 6	1.41e-03
# 7	7.84e-04
# 8	4.44e-04
# 9	2.56e-04
# 10	1.50e-04
# 11	8.83e-05
# iter	epsilon
# 1	3.40e+03
# 2	2.70e-02
# 3	1.13e-02
# 4	5.82e-03
# 5	3.18e-03
# 6	1.76e-03
# 7	9.89e-04
# 8	5.62e-04
# 9	3.21e-04
# 10	1.85e-04
# 11	1.07e-04
# 12	6.25e-05
# iter	epsilon
# 1	4.73e+02
# 2	6.11e-02
# 3	2.03e-02
# 4	1.00e-02
# 5	5.40e-03
# 6	3.05e-03
# 7	1.76e-03
# 8	1.03e-03
# 9	6.02e-04
# 10	3.56e-04
# 11	2.12e-04
# 12	1.27e-04
# 13	7.60e-05
# iter	epsilon
# 1	4.57e+02
# 2	6.38e-02
# 3	2.29e-02
# 4	1.14e-02
# 5	5.98e-03
# 6	3.28e-03
# 7	1.85e-03
# 8	1.05e-03
# 9	6.03e-04
# 10	3.47e-04
# 11	2.00e-04
# 12	1.16e-04
# 13	6.78e-05
# iter	epsilon
# 1	1.05e+03
# 2	4.50e-02
# 3	1.64e-02
# 4	7.98e-03
# 5	4.24e-03
# 6	2.35e-03
# 7	1.33e-03
# 8	7.63e-04
# 9	4.41e-04
# 10	2.56e-04
# 11	1.48e-04
# 12	8.63e-05
# iter	epsilon
# 1	1.10e+03
# 2	3.81e-02
# 3	1.54e-02
# 4	7.42e-03
# 5	3.74e-03
# 6	1.95e-03
# 7	1.04e-03
# 8	5.75e-04
# 9	3.22e-04
# 10	1.84e-04
# 11	1.06e-04
# 12	6.24e-05
# done
# /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo/df_8
# iter	epsilon
# 1	4.04e+03
# 2	2.57e-02
# 3	9.87e-03
# 4	5.05e-03
# 5	2.76e-03
# 6	1.55e-03
# 7	8.79e-04
# 8	5.05e-04
# 9	2.92e-04
# 10	1.70e-04
# 11	9.93e-05
# iter	epsilon
# 1	2.73e+03
# 2	3.86e-02
# 3	1.44e-02
# 4	6.80e-03
# 5	3.45e-03
# 6	1.80e-03
# 7	9.58e-04
# 8	5.16e-04
# 9	2.82e-04
# 10	1.57e-04
# 11	8.79e-05
# iter	epsilon
# 1	4.18e+02
# 2	7.68e-02
# 3	2.96e-02
# 4	1.33e-02
# 5	6.31e-03
# 6	3.25e-03
# 7	1.82e-03
# 8	1.05e-03
# 9	6.18e-04
# 10	3.69e-04
# 11	2.22e-04
# 12	1.35e-04
# 13	8.15e-05
# iter	epsilon
# 1	3.72e+02
# 2	8.03e-02
# 3	2.64e-02
# 4	1.11e-02
# 5	5.29e-03
# 6	2.73e-03
# 7	1.49e-03
# 8	8.42e-04
# 9	4.81e-04
# 10	2.77e-04
# 11	1.60e-04
# 12	9.32e-05
# iter	epsilon
# 1	9.73e+02
# 2	4.46e-02
# 3	1.76e-02
# 4	8.82e-03
# 5	4.90e-03
# 6	2.80e-03
# 7	1.63e-03
# 8	9.53e-04
# 9	5.61e-04
# 10	3.32e-04
# 11	1.98e-04
# 12	1.19e-04
# 13	7.17e-05
# iter	epsilon
# 1	1.57e+03
# 2	4.18e-02
# 3	1.76e-02
# 4	9.15e-03
# 5	5.16e-03
# 6	2.99e-03
# 7	1.75e-03
# 8	1.03e-03
# 9	6.12e-04
# 10	3.64e-04
# 11	2.18e-04
# 12	1.30e-04
# 13	7.83e-05
# done
# /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo/df_9
# iter	epsilon
# 1	4.51e+03
# 2	2.60e-02
# 3	1.05e-02
# 4	4.98e-03
# 5	2.50e-03
# 6	1.32e-03
# 7	7.28e-04
# 8	4.13e-04
# 9	2.42e-04
# 10	1.43e-04
# 11	8.60e-05
# iter	epsilon
# 1	3.37e+03
# 2	2.85e-02
# 3	1.32e-02
# 4	7.09e-03
# 5	4.00e-03
# 6	2.29e-03
# 7	1.33e-03
# 8	7.77e-04
# 9	4.59e-04
# 10	2.74e-04
# 11	1.64e-04
# 12	9.85e-05
# iter	epsilon
# 1	5.85e+02
# 2	5.62e-02
# 3	2.12e-02
# 4	1.03e-02
# 5	5.62e-03
# 6	3.16e-03
# 7	1.83e-03
# 8	1.07e-03
# 9	6.33e-04
# 10	3.78e-04
# 11	2.27e-04
# 12	1.37e-04
# 13	8.23e-05
# iter	epsilon
# 1	3.70e+02
# 2	9.09e-02
# 3	3.03e-02
# 4	1.15e-02
# 5	5.43e-03
# 6	2.85e-03
# 7	1.59e-03
# 8	8.98e-04
# 9	5.14e-04
# 10	3.01e-04
# 11	1.78e-04
# 12	1.06e-04
# 13	6.39e-05
# iter	epsilon
# 1	4.66e+02
# 2	5.29e-02
# 3	2.17e-02
# 4	1.06e-02
# 5	5.65e-03
# 6	3.13e-03
# 7	1.78e-03
# 8	1.02e-03
# 9	5.97e-04
# 10	3.52e-04
# 11	2.10e-04
# 12	1.26e-04
# 13	7.65e-05
# iter	epsilon
# 1	7.97e+02
# 2	5.79e-02
# 3	2.06e-02
# 4	1.09e-02
# 5	6.17e-03
# 6	3.55e-03
# 7	2.06e-03
# 8	1.20e-03
# 9	7.02e-04
# 10	4.12e-04
# 11	2.43e-04
# 12	1.44e-04
# 13	8.54e-05
# done
# /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo/df_10
# iter	epsilon
# 1	5.06e+03
# 2	2.49e-02
# 3	1.07e-02
# 4	5.32e-03
# 5	2.77e-03
# 6	1.47e-03
# 7	7.95e-04
# 8	4.34e-04
# 9	2.39e-04
# 10	1.36e-04
# 11	7.93e-05
# iter	epsilon
# 1	2.96e+03
# 2	2.87e-02
# 3	1.12e-02
# 4	5.40e-03
# 5	2.79e-03
# 6	1.52e-03
# 7	8.49e-04
# 8	4.84e-04
# 9	2.79e-04
# 10	1.63e-04
# 11	9.58e-05
# iter	epsilon
# 1	5.27e+02
# 2	6.07e-02
# 3	2.74e-02
# 4	1.47e-02
# 5	8.31e-03
# 6	4.78e-03
# 7	2.79e-03
# 8	1.65e-03
# 9	9.78e-04
# 10	5.85e-04
# 11	3.51e-04
# 12	2.12e-04
# 13	1.28e-04
# 14	7.76e-05
# iter	epsilon
# 1	3.97e+02
# 2	8.60e-02
# 3	2.78e-02
# 4	1.38e-02
# 5	7.43e-03
# 6	4.05e-03
# 7	2.20e-03
# 8	1.20e-03
# 9	6.53e-04
# 10	3.58e-04
# 11	1.97e-04
# 12	1.09e-04
# 13	6.10e-05
# iter	epsilon
# 1	5.87e+02
# 2	5.45e-02
# 3	1.94e-02
# 4	9.07e-03
# 5	4.68e-03
# 6	2.50e-03
# 7	1.36e-03
# 8	7.59e-04
# 9	4.29e-04
# 10	2.46e-04
# 11	1.43e-04
# 12	8.41e-05
# iter	epsilon
# 1	5.67e+02
# 2	5.87e-02
# 3	2.54e-02
# 4	1.24e-02
# 5	6.35e-03
# 6	3.32e-03
# 7	1.76e-03
# 8	9.49e-04
# 9	5.32e-04
# 10	3.03e-04
# 11	1.76e-04
# 12	1.03e-04
# 13	6.05e-05
# done
# /Users/liz/Documents/back_projection_home/backprojection-SARS-CoV-2-main/simulations/back-projected-redo/df_11
# iter	epsilon
# 1	3.33e+03
# 2	3.25e-02
# 3	1.33e-02
# 4	6.98e-03
# 5	3.90e-03
# 6	2.23e-03
# 7	1.29e-03
# 8	7.44e-04
# 9	4.33e-04
# 10	2.54e-04
# 11	1.50e-04
# 12	8.83e-05
# iter	epsilon
# 1	3.99e+03
# 2	2.78e-02
# 3	1.21e-02
# 4	6.09e-03
# 5	3.21e-03
# 6	1.72e-03
# 7	9.32e-04
# 8	5.10e-04
# 9	2.82e-04
# 10	1.58e-04
# 11	8.99e-05
# iter	epsilon
# 1	5.31e+02
# 2	6.58e-02
# 3	2.67e-02
# 4	1.42e-02
# 5	8.00e-03
# 6	4.58e-03
# 7	2.65e-03
# 8	1.55e-03
# 9	9.09e-04
# 10	5.36e-04
# 11	3.17e-04
# 12	1.88e-04
# 13	1.12e-04
# 14	6.70e-05
# iter	epsilon
# 1	5.31e+02
# 2	6.40e-02
# 3	2.69e-02
# 4	1.35e-02
# 5	7.07e-03
# 6	3.74e-03
# 7	2.00e-03
# 8	1.09e-03
# 9	5.98e-04
# 10	3.33e-04
# 11	1.88e-04
# 12	1.07e-04
# 13	6.18e-05
# iter	epsilon
# 1	3.68e+02
# 2	5.97e-02
# 3	2.42e-02
# 4	1.17e-02
# 5	5.94e-03
# 6	3.14e-03
# 7	1.73e-03
# 8	9.83e-04
# 9	5.76e-04
# 10	3.44e-04
# 11	2.08e-04
# 12	1.28e-04
# 13	7.94e-05
# iter	epsilon
# 1	1.34e+03
# 2	3.37e-02
# 3	1.39e-02
# 4	6.91e-03
# 5	3.71e-03
# 6	2.06e-03
# 7	1.17e-03
# 8	6.84e-04
# 9	4.07e-04
# 10	2.45e-04
# 11	1.49e-04
# 12	9.11e-05
# done
# CPU times: user 1h 4min 55s, sys: 2min 12s, total: 1h 7min 8s
# Wall time: 1h 9min 39s

# %% [markdown]
# <a id="14"></a>
# ## back projection reformatting

# %% [markdown]
# <a id="15"></a>
# ### parallel for 10 parent directories
# to aid with timing issue in large objects
#
# not finished with testing

# %%
# parallel (untested)

script_file            = 'back-projected-npz.py'
#script_path            = ppath.join(SIM_DIR, script_file)
#script_path_clust      = ppath.join(SSH_DATA, script_file)

bp_read_str       = 'back-projected-sim1000'
bp_write_str    =  'back-projected-sim1000-write'

dirs_write = []
dirs_read = []
for i in range(10):
    #for j in range(1000):
    write_str = bp_write_str + f'-{i}'
    read_str = bp_read_str + f'-{i}'
    
    dirs_write.append(write_str)
    dirs_read.append(read_str)

for i in range(10):    
    
    job_file         = f'job-bp-npz-1000-{i}.sh'
    job_str          = f"""#!/bin/bash -l
#SBATCH --job-name=bp-npz-1000-{i}
#SBATCH --output=bp-npz-1000-{i}.out
#SBATCH --error=bp-npz-1000-{i}.err
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=1
#SBATCH --mem=32G
#SBATCH --mail-user={USER_EMAIL}
#SBATCH --mail-type=ALL
#SBATCH --time=1-0

module unload miniconda2
module load miniconda3
conda activate sars-env

python {script_file} -npz_file {sim_npz_clust} -npz_base_name {sim_name} -WRITE_DIR {BP_PROJ_DIR_WRITE}
""" 

    f = open(os.path.join(SIM_DIR, job_file), mode='w')
    f.write('%s\n' % job_str)
    f.close()

#print(f'scp {script_path} {SSH_HOME}{SSH_DATA} &&')

job_path = os.path.join(SIM_DIR, job_file)

print(f'scp {job_path} {SSH_HOME}{SSH_DATA}')

print('')

# commands to execute on the cluster
print('sbatch %s' % job_file)
print('')

# %% [markdown]
# <a id="16"></a>
# ### large object reformatting
# formats the large object back projected output, runs relatively quickly

# %%
script_file            = 'back-projected-npz.py'
script_path            = ppath.join(SIM_DIR, script_file)
script_path_clust      = ppath.join(SSH_DATA, script_file)


job_file         = 'job-bp-npz-format.sh'
job_str          = f"""#!/bin/bash -l
#!/bin/bash
#SBATCH --job-name=bp-npz-10000
#SBATCH --output=bp-npz.out
#SBATCH --error=bp-npz.err
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=1
#SBATCH --mem=64G
#SBATCH --mail-user={USER_EMAIL}
#SBATCH --mail-type=ALL
#SBATCH --time=3-0

module unload miniconda2
module load miniconda3
conda activate sars-env

python {script_file} -npz_file {sim_npz_clust} -npz_base_name {sim_name} -WRITE_DIR {BP_PROJ_DIR_WRITE}
""" 

f = open(os.path.join(SIM_DIR, job_file), mode='w')
f.write('%s\n' % job_str)
f.close()

print(f'scp {script_path} {SSH_HOME}{SSH_DATA} &&')

job_path = os.path.join(SIM_DIR, job_file)

print(f'scp {job_path} {SSH_HOME}{SSH_DATA}')

print('')

# commands to execute on the cluster
print('sbatch %s' % job_file)
print('')

# %% [markdown]
# <a id="17"></a>
# ### local running reformatting

# %%
# %run back-projected-npz -npz_file {sim_npz} -npz_base_name {sim_name} -WRITE_DIR {WRITE_TEST}

# %% [markdown]
# <a id="18"></a>
# # run inferences
# ### local running on transferred cluster files

# %% [markdown]
# #### to do: smarter file renaming
# below is a bandaid command line script

# %%
# this bash command renames the badly named dataframe directories

for d in df_*; do
    new_name=$(echo "$d" | awk -F_ '{printf "df_%04d", $2}')
    mv "$d" "$new_name"
done

# %% [markdown]
# ### inference running

# %%
# %%time

sim_name = 'sim-samp100-T100-sim10000'
inf_name = 'inf-samp100-T100-sim10000'


sim_out       = os.path.join(SIM_DIR, sim_name + '-stochastic')
inf_out       = os.path.join(SIM_DIR, inf_name + '-stochastic')

# shuffling files

sim_shuff_out = os.path.join(SIM_DIR, sim_name + '-shuffled')
inf_shuff_out = os.path.join(SIM_DIR, inf_name + '-shuffled')


sim_bp_out = os.path.join(SIM_DIR, sim_name + '-backprojected')
inf_bp_out = os.path.join(SIM_DIR, sim_name + '-backprojected')

# %run {inf_script} --data {sim_out + '.npz'} -o {inf_out} -R 2 --pop_size 10000
# %run {inf_script} --data {sim_shuff_out + '.npz'} -o {inf_shuff_out} -R 2 --pop_size 10000
# %run {inf_script} --data {sim_bp_out + '.npz'} -o {inf_bp_out} -R 2 --pop_size 10000
